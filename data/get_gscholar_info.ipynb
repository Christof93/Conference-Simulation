# %%
import requests
from scholarly import scholarly, ProxyGenerator
from neo4j import GraphDatabase
URI = "neo4j://localhost:7687"

# %%
pg = ProxyGenerator()
# success = pg.FreeProxies()
success = pg.ScraperAPI("b1bb916c1201f9bfc83672dfcc15e3d4")
if success:
    scholarly.use_proxy(pg)
else:
    print("No Proxy found.")

# %%
# Retrieve the author's data, fill-in, and print
# Get an iterator for the author results
search_query = scholarly.search_author('Masahiro Suzuki, weblab.t.u-tokyo.ac.jp')
# Retrieve the first result from the iterator
first_author_result = next(search_query)

# %%
more_info = scholarly.fill(first_author_result, sections=["indices"])

# %%
more_info
# Out:
# {'container_type': 'Author',
#  'filled': ['indices'],
#  'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#  'scholar_id': 'r2nt5kUAAAAJ',
#  'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=r2nt5kUAAAAJ',
#  'name': 'Masahiro Suzuki',
#  'affiliation': 'The University of Tokyo',
#  'email_domain': '@weblab.tu-tokyo.ac.jp',
#  'interests': ['Artificial intelligence', 'Deep learning'],
#  'citedby': 588,
#  'citedby5y': 490,
#  'hindex': 9,
#  'hindex5y': 9,
#  'i10index': 9,
#  'i10index5y': 8}

# %%
def run_cypher_match(neo4j_driver, db_name, query, params=None):
    session = neo4j_driver.session(database=db_name)
    try:
        result = session.run(query, parameters=params)
        return [line for line in result]
    finally:
        session.close()

def get_author_batch(size=50):
    with GraphDatabase.driver(URI, auth=("neo4j", "openreview")) as driver:
        batch = run_cypher_match(
        driver,
        "open-review-data",
        f"MATCH (a:Author) WHERE a.scholar_id IS NULL RETURN a.id AS id, a.name AS name LIMIT {size}",
    )
    return batch


def find_author_info_gscholar(id, name):
    if "@" in id:
        domain = id.split("@")[1]
        search_query = scholarly.search_author(f'{name}, {domain}')
        # Retrieve the first result from the iterator
        try:
            first_author_result = next(search_query)
            print("found with name and domain.")
        except StopIteration:
            search_query = scholarly.search_author(f'{name}')
            try:
                first_author_result = next(search_query)
                print("found with name.")
            except StopIteration:
                return
        try:
            more_info = scholarly.fill(first_author_result, sections=["indices"])
            print(more_info)
            del more_info["container_type"]
            del more_info["name"]
            del more_info["source"]
            del more_info["url_picture"]
            del more_info["filled"]
            return more_info
        except:
            print("Couldn't extract hindex")
            return
    else:
        search_query = scholarly.search_author(f'{name}')
        try:
            first_author_result = next(search_query)
        except StopIteration:
            return

def set_author_gscholar_info(id, gscholar_properties):
    query = """
    MATCH (a:Author {id: $id})
    SET a += $newProperties
    RETURN a
    """    
    with GraphDatabase.driver(URI, auth=("neo4j", "openreview")) as driver:
        with driver.session(database="open-review-data") as session:
            session.execute_write(lambda tx: tx.run(query, id=id, newProperties=gscholar_properties))

# %%
def main():
    author_batch = get_author_batch()
    while len(author_batch)>0:
        for author in author_batch:
            print(author)
            info = find_author_info_gscholar(author["id"], author["name"])
            if info is not None:
                set_author_gscholar_info(author["id"], info)
            else:
                print("author not found on gscholar")
                set_author_gscholar_info(author["id"], {"scholar_id": "na"})
        author_batch = get_author_batch()

# %%
main()
# Out:
# <Record id='sylvaingelly@google.com' name='Sylvain Gelly'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'm7LvuTkAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=m7LvuTkAAAAJ', 'name': 'Sylvain Gelly', 'affiliation': 'Google Brain Zurich', 'email_domain': '@m4x.org', 'interests': ['Machine Learning', 'Artificial Intelligence', 'Reinforcement Learning'], 'citedby': 48358, 'citedby5y': 45288, 'hindex': 45, 'hindex5y': 40, 'i10index': 72, 'i10index5y': 59}
# <Record id='bs@tuebingen.mpg.de' name='Bernhard Sch ̈olkopf'>
# author not found on gscholar
# <Record id='abdu@weblab.t.u-tokyo.ac.jp' name='Abdul Rahman Abdul Ghani'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': '8ery-IUAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=8ery-IUAAAAJ', 'name': 'Abdul Rahman  A.Ghani', 'affiliation': 'Profesor Evaluasi Pendidikan, Universitas Muhammadiyah Prof. Dr. HAMKA', 'email_domain': '@uhamka.ac.id', 'interests': ['Penelitian dan Evaluasi Pendidikan', 'Administrasi Pendidikan'], 'citedby': 241, 'citedby5y': 218, 'hindex': 8, 'hindex5y': 7, 'i10index': 5, 'i10index5y': 5}
# <Record id='nishanth-k@is.naist.jp' name='Nishanth Koganti'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'X_kPcpEAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=X_kPcpEAAAAJ', 'name': 'Nishanth Koganti', 'affiliation': 'Fovea Technology LLC', 'email_domain': '@exwzd.in', 'interests': ['Robotics', 'Reinforcement Learning', 'Computer Vision', 'Natural Language Processing'], 'citedby': 305, 'citedby5y': 257, 'hindex': 11, 'hindex5y': 10, 'i10index': 11, 'i10index5y': 10}
# <Record id='asolano@weblab.t.u-tokyo.ac.jp' name='Alfredo Solano'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'Nm09znsAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=Nm09znsAAAAJ', 'name': 'Alfredo Bueno-solano', 'affiliation': 'Professor', 'email_domain': '@itson.edu.mx', 'interests': ['Engineering'], 'citedby': 1893, 'citedby5y': 874, 'hindex': 12, 'hindex5y': 11, 'i10index': 13, 'i10index5y': 11}
# <Record id='iwasawa@weblab.t.u-tokyo.ac.jp' name='Yusuke Iwasawa'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'nRLaJiQAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=nRLaJiQAAAAJ', 'name': 'Yusuke Iwasawa', 'affiliation': 'The University of Tokyo', 'email_domain': '@weblab.tu-tokyo.ac.jp', 'interests': ['deep learning', 'transfer learning', 'foundation model', 'meta learning'], 'citedby': 2644, 'citedby5y': 2578, 'hindex': 16, 'hindex5y': 14, 'i10index': 21, 'i10index5y': 18}
# <Record id='nakayama@weblab.t.u-tokyo.ac.jp' name='Kotaro Nakayama'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'MT4jukMAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=MT4jukMAAAAJ', 'name': 'Kotaro Nakayama', 'affiliation': 'NABLAS Inc.', 'email_domain': '@nablas.com', 'interests': ['Artificial Intelligence', 'Scalability', 'Deep Learning', 'Web Mining'], 'citedby': 1877, 'citedby5y': 858, 'hindex': 21, 'hindex5y': 12, 'i10index': 32, 'i10index5y': 12}
# <Record id='anmelnik@techfak.uni-bielefeld.de' name='Andrew Melnik'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'INiyBUIAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=INiyBUIAAAAJ', 'name': 'Andrew Melnyk', 'affiliation': 'Professor of Philosophy, University of Missouri', 'email_domain': '@missouri.edu', 'interests': ['philosophy of mind', 'metaphysics', 'philosophy of science', 'metaphilosophy'], 'citedby': 1184, 'citedby5y': 282, 'hindex': 17, 'hindex5y': 9, 'i10index': 18, 'i10index5y': 8}
# <Record id='sfleer@techfak.uni-bielefeld.de' name='Sascha Fleer'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'WSUwphwAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=WSUwphwAAAAJ', 'name': 'Sascha Fleer', 'affiliation': '', 'email_domain': '@techfak.uni-bielefeld.de', 'interests': [], 'citedby': 125, 'citedby5y': 123, 'hindex': 3, 'hindex5y': 3, 'i10index': 3, 'i10index5y': 3}
# <Record id='mschilli@techfak.uni-bielefeld.de' name='Malte Schilling'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'LtQzuTAAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=LtQzuTAAAAAJ', 'name': 'Malte Schilling', 'affiliation': 'Professor, Autonomous Intelligent Systems Group', 'email_domain': '@uni-muenster.de', 'interests': ['Machine Learning', 'Cognition', 'Robotics', 'Neural Networks'], 'citedby': 1445, 'citedby5y': 799, 'hindex': 21, 'hindex5y': 15, 'i10index': 37, 'i10index5y': 25}
# <Record id='helge@techfak.uni-bielefeld.de' name='Helge Ritter'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'yplv734AAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=yplv734AAAAJ', 'name': 'Helge Ritter', 'affiliation': 'Professor of Neuroinformatics, Bielefeld University', 'email_domain': '@techfak.uni-bielefeld.de', 'interests': ['neuroinformatics and cognitive systems', 'interfaces and interaction technologies'], 'citedby': 19866, 'citedby5y': 3716, 'hindex': 65, 'hindex5y': 27, 'i10index': 295, 'i10index5y': 103}
# <Record id='doronsobol@gmail.com' name='Doron Sobol'>
# author not found on gscholar
# <Record id='wolf@fb.com' name='Lior Wolf'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'UbFrXTsAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=UbFrXTsAAAAJ', 'name': 'Lior Wolf', 'affiliation': 'The School of Computer Science at Tel Aviv University', 'email_domain': '@cs.tau.ac.il', 'interests': [], 'citedby': 36515, 'citedby5y': 20311, 'hindex': 76, 'hindex5y': 62, 'i10index': 242, 'i10index5y': 203}
# <Record id='yaniv@fb.com' name='Yaniv Taigman'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'mbB3MRIAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=mbB3MRIAAAAJ', 'name': 'Yaniv Taigman', 'affiliation': 'Facebook AI Research', 'email_domain': '@fb.com', 'interests': ['machine learning', 'computer vision'], 'citedby': 14246, 'citedby5y': 8638, 'hindex': 30, 'hindex5y': 29, 'i10index': 33, 'i10index5y': 32}
# <Record id='shikhar.sharma@microsoft.com' name='Shikhar Sharma'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'bLA7DYwAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=bLA7DYwAAAAJ', 'name': 'Shikhar Sharma', 'affiliation': 'Microsoft', 'email_domain': '@microsoft.com', 'interests': ['Deep Learning', 'Machine Learning', 'Computer Vision', 'Natural Language Processing', 'Adversarial Learning'], 'citedby': 2032, 'citedby5y': 1622, 'hindex': 14, 'hindex5y': 14, 'i10index': 15, 'i10index5y': 14}
# <Record id='suhubdyd@iro.umontreal.ca' name='Dendi Suhubdy'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'oX6KoJcAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=oX6KoJcAAAAJ', 'name': 'Dendi Suhubdy', 'affiliation': 'Researcher, MILA', 'email_domain': '@bitwyre.com', 'interests': ['deep learning', 'machine learning', 'algorithmic stability'], 'citedby': 559, 'citedby5y': 475, 'hindex': 7, 'hindex5y': 6, 'i10index': 5, 'i10index5y': 4}
# <Record id='vincent.michalski@umontreal.ca' name='Vincent Michalski'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': '9BGzHdUAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=9BGzHdUAAAAJ', 'name': 'Vincent Michalski', 'affiliation': 'Ph.D. candidate at Université de Montréal', 'email_domain': '@umontreal.ca', 'interests': ['machine learning', 'deep learning', 'computer vision'], 'citedby': 5068, 'citedby5y': 3975, 'hindex': 15, 'hindex5y': 14, 'i10index': 17, 'i10index5y': 15}
# <Record id='samira.ebrahimi@microsoft.com' name='Samira Ebrahimi Kahou'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'F99FuaAAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=F99FuaAAAAAJ', 'name': 'Samira Ebrahimi Kahou', 'affiliation': 'Associate Professor, École de technologie supérieure/Mila/Canada CIFAR AI Chair', 'email_domain': '@etsmtl.ca', 'interests': ['Machine Learning', 'Computer Vision', 'Deep Learning', 'Multimodal Learning', 'Reinforcement Learning'], 'citedby': 8225, 'citedby5y': 6647, 'hindex': 22, 'hindex5y': 21, 'i10index': 29, 'i10index5y': 29}
# <Record id='yoshua.umontreal@gmail.com' name='Yoshua Bengio'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'kukA0LcAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=kukA0LcAAAAJ', 'name': 'Yoshua Bengio', 'affiliation': 'Professor of computer science, University of Montreal, Mila, IVADO, CIFAR', 'email_domain': '@umontreal.ca', 'interests': ['Machine learning', 'deep learning', 'artificial intelligence'], 'citedby': 764364, 'citedby5y': 582191, 'hindex': 229, 'hindex5y': 198, 'i10index': 826, 'i10index5y': 723}
# <Record id='reagen@fas.harvard.edu' name='Brandon Reagen'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'cO2uYoAAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=cO2uYoAAAAAJ', 'name': 'Brandon Reagen', 'affiliation': 'Assistant Professor, New York University', 'email_domain': '@nyu.edu', 'interests': ['Computer Architecture', 'Machine Learning', 'Privacy', 'VLSI'], 'citedby': 4049, 'citedby5y': 3478, 'hindex': 25, 'hindex5y': 23, 'i10index': 30, 'i10index5y': 29}
# <Record id='ugupta@g.harvard.edu' name='Udit Gupta'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'LIPcHGQAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=LIPcHGQAAAAJ', 'name': 'Udit Gupta', 'affiliation': 'Assistant Professor', 'email_domain': '@cornell.edu', 'interests': ['Computer Architecture', 'Systems for Machine Learning', 'Environmentally Sustainable Computing'], 'citedby': 3017, 'citedby5y': 2960, 'hindex': 23, 'hindex5y': 21, 'i10index': 25, 'i10index5y': 25}
# <Record id='rdadolf@seas.harvard.edu' name='Robert Adolf'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'XZCU8NsAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=XZCU8NsAAAAJ', 'name': 'Robert A. Hoyt', 'affiliation': 'Postdoctoral Researcher, Harvard University', 'email_domain': '@seas.harvard.edu', 'interests': ['Catalysis', 'Machine Learning', 'Density Functional Theory'], 'citedby': 249, 'citedby5y': 208, 'hindex': 7, 'hindex5y': 7, 'i10index': 6, 'i10index5y': 6}
# <Record id='michaelm@eecs.harvard.edu' name='Michael Mitzenmacher'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'e8aRmAsAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=e8aRmAsAAAAJ', 'name': 'Michael Mitzenmacher', 'affiliation': 'Professor of Computer Science, Harvard University', 'email_domain': '@eecs.harvard.edu', 'interests': ['Randomized Algorithms', 'Internet Algorithms', 'Networking', 'Information Theory'], 'citedby': 48042, 'citedby5y': 13555, 'hindex': 90, 'hindex5y': 48, 'i10index': 265, 'i10index5y': 160}
# <Record id='srush@seas.harvard.edu' name='Alexander M. Rush'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'LIjnUGgAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=LIjnUGgAAAAJ', 'name': 'Alexander M. Rush', 'affiliation': 'Associate Professor, Cornell University', 'email_domain': '@cornell.edu', 'interests': ['Natural Language Processing', 'Machine Learning'], 'citedby': 31548, 'citedby5y': 26615, 'hindex': 61, 'hindex5y': 54, 'i10index': 114, 'i10index5y': 106}
# <Record id='gywei@g.harvard.edu' name='Gu-Yeon Wei'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'IR0yJB8AAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=IR0yJB8AAAAJ', 'name': 'Gu-Yeon Wei', 'affiliation': 'Robert and Suzanne Case Professor of EE and CS, Harvard University', 'email_domain': '@eecs.harvard.edu', 'interests': ['integrated circuits', 'computer architecture'], 'citedby': 14422, 'citedby5y': 6944, 'hindex': 59, 'hindex5y': 39, 'i10index': 163, 'i10index5y': 111}
# <Record id='dbrooks@eecs.harvard.edu' name='David Brooks'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'vXHA_XYAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=vXHA_XYAAAAJ', 'name': 'David Brooks', 'affiliation': 'Haley Family Professor of Computer Science, Harvard University', 'email_domain': '@eecs.harvard.edu', 'interests': ['Computer Architecture'], 'citedby': 23732, 'citedby5y': 9288, 'hindex': 66, 'hindex5y': 44, 'i10index': 183, 'i10index5y': 122}
# <Record id='rach0012@berkeley.edu' name='Rachit Dubey'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'fJsSvzkAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=fJsSvzkAAAAJ', 'name': 'Rachit Dubey', 'affiliation': 'Postdoctoral Fellow, MIT Sloan', 'email_domain': '@mit.edu', 'interests': ['Cognitive Psychology', 'Sustainability', 'Climate Change', 'Computational modeling', 'Reinforcement learning'], 'citedby': 711, 'citedby5y': 612, 'hindex': 9, 'hindex5y': 8, 'i10index': 9, 'i10index5y': 7}
# <Record id='pulkitag@berkeley.edu' name='Pulkit Agrawal'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'UpZmJI0AAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=UpZmJI0AAAAJ', 'name': 'Pulkit Agrawal', 'affiliation': 'Massachusetts Institute of Technology', 'email_domain': '@mit.edu', 'interests': ['Robotics', 'Computer Vision', 'Artificial Intelligence', 'Reinforcement Learning'], 'citedby': 10124, 'citedby5y': 8484, 'hindex': 33, 'hindex5y': 33, 'i10index': 52, 'i10index5y': 50}
# <Record id='pathak@berkeley.edu' name='Deepak Pathak'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'AEsPCAUAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=AEsPCAUAAAAJ', 'name': 'Deepak Pathak', 'affiliation': 'Assistant Professor, Carnegie Mellon University', 'email_domain': '@cs.cmu.edu', 'interests': ['Computer Vision', 'Deep Learning', 'Robotics', 'Reinforcement Learning'], 'citedby': 17438, 'citedby5y': 15600, 'hindex': 38, 'hindex5y': 38, 'i10index': 64, 'i10index5y': 62}
# <Record id='efros@eecs.berkeley.edu' name='Alexei A. Efros'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'd97bGd8AAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=d97bGd8AAAAJ', 'name': 'Alexei A. Efros', 'affiliation': 'UC Berkeley', 'email_domain': '@eecs.berkeley.edu', 'interests': ['computer vision', 'machine learning', 'computer graphics', 'computational photography'], 'citedby': 127807, 'citedby5y': 94442, 'hindex': 106, 'hindex5y': 85, 'i10index': 159, 'i10index5y': 145}
# <Record id='tom_griffiths@berkeley.edu' name='Thomas L. Griffiths'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'UAwKvEsAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=UAwKvEsAAAAJ', 'name': 'Thomas L. Griffiths', 'affiliation': 'Professor of Psychology and Computer Science, Princeton University', 'email_domain': '@princeton.edu', 'interests': ['Computational Models of Cognition', 'Cognitive Science', 'Machine Learning', 'Cognitive Psychology', 'Bayesian Statistics'], 'citedby': 64486, 'citedby5y': 29557, 'hindex': 110, 'hindex5y': 79, 'i10index': 355, 'i10index5y': 292}
# <Record id='catalina.cangea@cst.cam.ac.uk' name='Cătălina Cangea'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'Y0yIZpMAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=Y0yIZpMAAAAJ', 'name': 'Cătălina Cangea', 'affiliation': 'Senior Research Scientist, Google DeepMind', 'email_domain': '@google.com', 'interests': ['Machine Learning', 'Multimodal Learning', 'Generative AI', 'Music Generation'], 'citedby': 742, 'citedby5y': 738, 'hindex': 11, 'hindex5y': 11, 'i10index': 11, 'i10index5y': 11}
# <Record id='petar.velickovic@cst.cam.ac.uk' name='Petar Velickovic'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'kcTK_FAAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=kcTK_FAAAAAJ', 'name': 'Petar Veličković', 'affiliation': 'Staff Research Scientist, Google DeepMind | Affiliated Lecturer, University of Cambridge', 'email_domain': '@deepmind.com', 'interests': ['Geometric Deep Learning', 'Graph Representation Learning', 'Graph Neural Networks', 'Algorithmic Reasoning', 'Computational Biology'], 'citedby': 26338, 'citedby5y': 26129, 'hindex': 32, 'hindex5y': 30, 'i10index': 51, 'i10index5y': 50}
# <Record id='pietro.lio@cst.cam.ac.uk' name='Pietro Liò'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': '4YhNJBEAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=4YhNJBEAAAAJ', 'name': 'Pietro Liò', 'affiliation': 'Professor, University of Cambridge', 'email_domain': '@cam.ac.uk', 'interests': ['AI & Comp Biology -> Medicine'], 'citedby': 51459, 'citedby5y': 41541, 'hindex': 67, 'hindex5y': 56, 'i10index': 335, 'i10index5y': 243}
# <Record id='hyhieu@cmu.edu' name='Hieu Pham'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': '0RvAVR4AAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=0RvAVR4AAAAJ', 'name': 'Hieu Pham', 'affiliation': 'Stealth startup. Past: Google Brain.', 'email_domain': '', 'interests': ['Machine Learning'], 'citedby': 20037, 'citedby5y': 17681, 'hindex': 22, 'hindex5y': 22, 'i10index': 23, 'i10index5y': 23}
# <Record id='mguan@stanford.edu' name='Melody Y. Guan'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'yt9bJUcAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=yt9bJUcAAAAJ', 'name': 'Melody Y. Guan', 'affiliation': 'Stanford University', 'email_domain': '@stanford.edu', 'interests': ['Machine Learning', 'Deep Learning'], 'citedby': 4190, 'citedby5y': 4056, 'hindex': 8, 'hindex5y': 8, 'i10index': 8, 'i10index5y': 8}
# <Record id='barretzoph@google.com' name='Barret Zoph'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'NL_7iTwAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=NL_7iTwAAAAJ', 'name': 'Barret Zoph', 'affiliation': 'OpenAI', 'email_domain': '@openai.com', 'interests': [], 'citedby': 51312, 'citedby5y': 49698, 'hindex': 53, 'hindex5y': 52, 'i10index': 67, 'i10index5y': 65}
# <Record id='qvl@google.com' name='Quoc V. Le'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': '7lgMtfwAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=7lgMtfwAAAAJ', 'name': 'Trường Cao đẳng Công nghệ Y dược Việt Nam', 'affiliation': '… : 0896464666 Google map: https://www.google.com/maps?cid=5873090316978921347 …', 'email_domain': '', 'interests': ['Cao đẳng y dược'], 'hindex': 0, 'hindex5y': 0, 'i10index': 0, 'i10index5y': 0}
# <Record id='jeff@google.com' name='Jeff Dean'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'NMS69lQAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=NMS69lQAAAAJ', 'name': 'Jeff Dean', 'affiliation': 'Google Chief Scientist, Google Research and Google DeepMind', 'email_domain': '@google.com', 'interests': ['Distributed systems', 'information retrieval', 'machine learning', 'compilers', 'computer architecture'], 'citedby': 285228, 'citedby5y': 179718, 'hindex': 98, 'hindex5y': 71, 'i10index': 274, 'i10index5y': 179}
# <Record id='george.philipp@email.de' name='George Philipp'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': '66BcnF0AAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=66BcnF0AAAAJ', 'name': 'George Malliaras', 'affiliation': 'Prince Philip Professor of Technology at University of Cambridge', 'email_domain': '@cam.ac.uk', 'interests': ['Bioelectronics'], 'citedby': 48931, 'citedby5y': 24447, 'hindex': 119, 'hindex5y': 78, 'i10index': 315, 'i10index5y': 249}
# <Record id='dawnsong@gmail.com' name='Dawn Song'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': '84WzBlYAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=84WzBlYAAAAJ', 'name': 'Dawn Song', 'affiliation': 'Professor of Computer Science, UC Berkeley', 'email_domain': '@cs.berkeley.edu', 'interests': ['Computer Security and Privacy'], 'citedby': 104609, 'citedby5y': 54347, 'hindex': 145, 'hindex5y': 107, 'i10index': 375, 'i10index5y': 316}
# <Record id='jgc@cs.cmu.edu' name='Jaime Carbonell'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': '0y6JDD4AAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=0y6JDD4AAAAJ', 'name': 'Mahadev Satyanarayanan', 'affiliation': 'Jaime Carbonell University Professor of Computer Science, Carnegie Mellon University', 'email_domain': '@cs.cmu.edu', 'interests': ['edge computing', 'mobile computing', 'Internet of Things', 'pervasive computing', 'distributed systems'], 'citedby': 45591, 'citedby5y': 11763, 'hindex': 88, 'hindex5y': 49, 'i10index': 209, 'i10index5y': 100}
# <Record id='yiming.zhang@nyu.edu' name='Yiming Zhang'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'A7-xkvcAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=A7-xkvcAAAAJ', 'name': 'Yiming Zhang', 'affiliation': 'New York University', 'email_domain': '@nyu.edu', 'interests': ['Reinforcement Learning'], 'citedby': 168, 'citedby5y': 168, 'hindex': 5, 'hindex5y': 5, 'i10index': 3, 'i10index5y': 3}
# <Record id='quan.vuong@nyu.edu' name='Quan Ho Vuong'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'Nn1C8zMAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=Nn1C8zMAAAAJ', 'name': 'Kí hiệu đặc biệt', 'affiliation': '… . Địa chỉ: 273 An D. Vương, Phường 3, Quận 5, Thành phố Hồ Chí Minh 700000 SĐT …', 'email_domain': '', 'interests': [], 'citedby': 7, 'citedby5y': 3, 'hindex': 2, 'hindex5y': 1, 'i10index': 0, 'i10index5y': 0}
# <Record id='kenny.song@nyu.edu' name='Kenny Song'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'EF-SzEUAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=EF-SzEUAAAAJ', 'name': 'Kenny Song', 'affiliation': 'University of Tokyo', 'email_domain': '@ms.ku-tokyo.ac.jp', 'interests': ['Adversarial Machine Learning', 'Trustworthy AI', 'AI Security', 'Reinforcement Learning'], 'citedby': 9, 'citedby5y': 9, 'hindex': 1, 'hindex5y': 1, 'i10index': 0, 'i10index5y': 0}
# <Record id='xygong@mit.edu' name='Xiao-Yue Gong'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'uHDiAKQAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=uHDiAKQAAAAJ', 'name': 'Xiao-Yue Gong', 'affiliation': 'Assistant Professor, Carnegie Mellon University', 'email_domain': '@andrew.cmu.edu', 'interests': ['reinforcement learning', 'supply chain', 'service operations', 'algorithms', 'revenue management'], 'citedby': 91, 'citedby5y': 91, 'hindex': 4, 'hindex5y': 4, 'i10index': 2, 'i10index5y': 2}
# <Record id='keithwross@nyu.edu' name='Keith Ross'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'RhUcYmQAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=RhUcYmQAAAAJ', 'name': 'Keith Ross', 'affiliation': 'Professor of Computer Science, NYU Abu Dhabi', 'email_domain': '@nyu.edu', 'interests': ['Deep Reinforcement Learning', 'Networking', 'Privacy'], 'citedby': 30400, 'citedby5y': 4891, 'hindex': 79, 'hindex5y': 29, 'i10index': 217, 'i10index5y': 79}
# <Record id='yun.chencreek@gmail.com' name='Yun Chen'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': '0F1cz3AAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=0F1cz3AAAAAJ', 'name': 'Teng-Yun Chen', 'affiliation': 'University of Science and Technology of China', 'email_domain': '@ustc.edu.cn', 'interests': ['quantum communication'], 'citedby': 6868, 'citedby5y': 4938, 'hindex': 36, 'hindex5y': 32, 'i10index': 49, 'i10index5y': 47}
# <Record id='kyunghyun.cho@nyu.edu' name='Kyunghyun Cho'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': '0RAmmIAAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=0RAmmIAAAAAJ', 'name': 'Kyunghyun Cho', 'affiliation': 'New York University, Genentech', 'email_domain': '@nyu.edu', 'interests': ['Machine Learning', 'Deep Learning'], 'citedby': 143530, 'citedby5y': 114574, 'hindex': 98, 'hindex5y': 91, 'i10index': 237, 'i10index5y': 224}
# <Record id='bowman@nyu.edu' name='Samuel R. Bowman'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'kV9XRxYAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=kV9XRxYAAAAJ', 'name': 'Samuel R. Bowman', 'affiliation': 'NYU and Anthropic', 'email_domain': '@nyu.edu', 'interests': ['natural language processing', 'computational linguistics', 'language model evaluation', 'AI alignment', 'scalable oversight'], 'citedby': 31815, 'citedby5y': 29590, 'hindex': 52, 'hindex5y': 51, 'i10index': 95, 'i10index5y': 90}
# <Record id='vli@eee.hku.hk' name='Victor O.K. Li'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'GKL_i6sAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=GKL_i6sAAAAJ', 'name': 'Victor OK Li', 'affiliation': 'The University of Hong Kong', 'email_domain': '@eee.hku.hk', 'interests': ['AI', 'big data', 'smart grid', 'networks', 'optimization techniques.'], 'citedby': 28238, 'citedby5y': 12338, 'hindex': 75, 'hindex5y': 52, 'i10index': 383, 'i10index5y': 175}
# <Record id='haihao.shen@intel.com' name='Haihao Shen'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': '2-lay2YAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=2-lay2YAAAAJ', 'name': 'Haihao Shen', 'affiliation': 'Intel', 'email_domain': '@intel.com', 'interests': ['Deep learning model compression'], 'citedby': 383, 'citedby5y': 231, 'hindex': 8, 'hindex5y': 5, 'i10index': 8, 'i10index5y': 4}
# <Record id='jiong.gong@intel.com' name='Jiong Gong'>
# author not found on gscholar
# <Record id='jianhui.li@intel.com' name='Jianhui Li'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'P8AdgT4AAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=P8AdgT4AAAAJ', 'name': 'Jianhui Li', 'affiliation': 'Xiamen University', 'email_domain': '@xmu.edu.cn', 'interests': ['catalysis', 'electrochemistry', 'fuel cells'], 'citedby': 880, 'citedby5y': 662, 'hindex': 15, 'hindex5y': 12, 'i10index': 17, 'i10index5y': 14}
# <Record id='xiaoli.liu@intel.com' name='Xiaoli Liu'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'C3L61hIAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=C3L61hIAAAAJ', 'name': 'Liu Xiaoli', 'affiliation': 'Shenzhen University', 'email_domain': '@szu.edu.cn', 'interests': [], 'citedby': 24186, 'citedby5y': 15508, 'hindex': 78, 'hindex5y': 61, 'i10index': 385, 'i10index5y': 336}
# <Record id='xinan.lin@intel.com' name='Xinan Lin'>
# author not found on gscholar
# <Record id='martin.simonovsky@enpc.fr' name='Martin Simonovsky'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'vfAir1cAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=vfAir1cAAAAJ', 'name': 'Martin Simonovsky', 'affiliation': 'Bosch', 'email_domain': '@enpc.fr', 'interests': ['Artificial Intelligence', 'Computer Vision', 'Machine Learning'], 'citedby': 3903, 'citedby5y': 3698, 'hindex': 6, 'hindex5y': 6, 'i10index': 6, 'i10index5y': 5}
# <Record id='nikos.komodakis@enpc.fr' name='Nikos Komodakis'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'xCPoT4EAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=xCPoT4EAAAAJ', 'name': 'Nikos Komodakis', 'affiliation': 'Assistant Professor, Computer Science Department, University of Crete', 'email_domain': '@csd.uoc.gr', 'interests': ['deep learning', 'computer vision', 'machine learning', 'medical image analysis', 'artificial intelligence'], 'citedby': 30970, 'citedby5y': 23368, 'hindex': 57, 'hindex5y': 42, 'i10index': 85, 'i10index5y': 61}
# <Record id='dlp@fb.com' name='David Lopez-Paz'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'SiCHxTkAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=SiCHxTkAAAAJ', 'name': 'David Lopez-Paz', 'affiliation': 'AI at Meta', 'email_domain': '@fb.com', 'interests': ['machine Learning', 'artificial intelligence', 'invariance', 'generalization', 'causality'], 'citedby': 20250, 'citedby5y': 19424, 'hindex': 31, 'hindex5y': 28, 'i10index': 42, 'i10index5y': 39}
# <Record id='levent.sagun@ipht.fr' name='Levent Sagun'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': '-iPZaBcAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=-iPZaBcAAAAJ', 'name': 'Levent Sagun', 'affiliation': 'FAIR', 'email_domain': '@meta.com', 'interests': ['machine learning', 'deep learning', 'probability', 'statistical physics', 'energy landscapes'], 'citedby': 3830, 'citedby5y': 3519, 'hindex': 17, 'hindex5y': 17, 'i10index': 22, 'i10index5y': 21}
# <Record id='dsculley@google.com' name='D. Sculley'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'l_O64B8AAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=l_O64B8AAAAJ', 'name': 'D. Sculley', 'affiliation': 'Kaggle & Google', 'email_domain': '@google.com', 'interests': ['Machine Learning', 'Data Mining'], 'citedby': 11764, 'citedby5y': 9116, 'hindex': 38, 'hindex5y': 35, 'i10index': 56, 'i10index5y': 48}
# <Record id='alexbw@google.com' name='Alex Wiltschko'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'GPnusKcAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=GPnusKcAAAAJ', 'name': 'Alexander Bame Wiltschko', 'affiliation': 'Osmo', 'email_domain': '@osmo.ai', 'interests': ['Olfaction', 'Artificial Intelligence', 'Neuroscience', 'Behavior'], 'citedby': 2902, 'citedby5y': 2224, 'hindex': 18, 'hindex5y': 18, 'i10index': 26, 'i10index5y': 26}
# <Record id='arahimi@google.com' name='Ali Rahimi'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'XXUsEjsAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=XXUsEjsAAAAJ', 'name': 'Ali Rahimi', 'affiliation': 'Psychologist tehran central azad university', 'email_domain': '@iauctb.ac.ir', 'interests': ['computer', 'systems', 'psychology', 'management', 'mechanic'], 'citedby': 13972, 'citedby5y': 7243, 'hindex': 44, 'hindex5y': 31, 'i10index': 155, 'i10index5y': 104}
# <Record id='smahdiz@ncsu.edu' name='Shahin Mahdizadehaghdam'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'jV23kBAAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=jV23kBAAAAAJ', 'name': 'Shahin Mahdizadehaghdam', 'affiliation': 'North Carolina State University', 'email_domain': '@ncsu.edu', 'interests': [], 'citedby': 259, 'citedby5y': 184, 'hindex': 6, 'hindex5y': 5, 'i10index': 5, 'i10index5y': 5}
# <Record id='apanahi@ncsu.edu' name='Ashkan Panahi'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'nq0JgwYAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=nq0JgwYAAAAJ', 'name': 'Ashkan Panahi', 'affiliation': 'Assistant Professor', 'email_domain': '@chalmers.se', 'interests': ['Machine Learning', 'Optimization Theory', 'Statistical Signal Processing', 'Information theory'], 'citedby': 939, 'citedby5y': 595, 'hindex': 16, 'hindex5y': 12, 'i10index': 24, 'i10index5y': 14}
# <Record id='ahkg@ncsu.edu' name='Hamid Krim'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': '0xHa9WYAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=0xHa9WYAAAAJ', 'name': 'Hamid Krim', 'affiliation': 'Professor of ECE, Director of VISSTA Laboratory, North Carolina State University', 'email_domain': '@ncsu.edu', 'interests': ['Estimation', 'Signal Processing', 'Statistical Signal and Image Analysis', 'Vision', 'Machine Learning'], 'citedby': 12656, 'citedby5y': 3172, 'hindex': 40, 'hindex5y': 19, 'i10index': 126, 'i10index5y': 43}
# <Record id='liyi.dai.civ@mail.mil' name='Liyi Dai'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'qDN_gSwAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=qDN_gSwAAAAJ', 'name': 'Liyi Dai', 'affiliation': 'Raytheon Technologies', 'email_domain': '@raytheon.com', 'interests': ['Machine Learning', 'Nonlinear Filtering', 'Discrete Event Dynamic Systems', 'Control', 'Optimization'], 'citedby': 7195, 'citedby5y': 1408, 'hindex': 26, 'hindex5y': 15, 'i10index': 41, 'i10index5y': 19}
# <Record id='anaon@anon.com' name='X'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'yuB-cfoAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=yuB-cfoAAAAJ', 'name': 'Xiangyu Zhang', 'affiliation': 'Principal Researcher, MEGVII Technology', 'email_domain': '@megvii.com', 'interests': ['Neural Network Architectures', 'Efficient Deep Learning', 'Computer Vision'], 'citedby': 284863, 'citedby5y': 253238, 'hindex': 52, 'hindex5y': 52, 'i10index': 82, 'i10index5y': 82}
# <Record id='romain.laroche@gmail.com' name='Romain Laroche'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'RiIOKJMAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=RiIOKJMAAAAJ', 'name': 'Romain Laroche', 'affiliation': 'Microsoft Research', 'email_domain': '@polytechnique.org', 'interests': ['Reinforcement Learning', 'Dialogue Systems'], 'citedby': 1733, 'citedby5y': 1275, 'hindex': 21, 'hindex5y': 17, 'i10index': 42, 'i10index5y': 27}
# <Record id='harm.vanseijen@microsoft.com' name='Harm van Seijen'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': '0UTNLh8AAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=0UTNLh8AAAAJ', 'name': 'Harm van Seijen', 'affiliation': 'Microsoft Research', 'email_domain': '@microsoft.com', 'interests': ['reinforcement learning', 'machine learning', 'representation learning'], 'citedby': 1616, 'citedby5y': 1305, 'hindex': 16, 'hindex5y': 15, 'i10index': 20, 'i10index5y': 16}
# <Record id='alexhg15@gmail.com' name='Alex Hernandez-Garcia'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'f8vQCOAAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=f8vQCOAAAAAJ', 'name': 'Alex Hernández-García', 'affiliation': 'Mila, Université de Montréal', 'email_domain': '@mila.quebec', 'interests': ['machine learning', 'computer vision', 'computational neuroscience', 'visual perception'], 'citedby': 689, 'citedby5y': 654, 'hindex': 12, 'hindex5y': 11, 'i10index': 16, 'i10index5y': 15}
# <Record id='pkoenig@uos.de' name='Peter König'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'Ieubd0EAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=Ieubd0EAAAAJ', 'name': 'Peter König', 'affiliation': 'Cognitive Science, University Osnabrück', 'email_domain': '@uos.de', 'interests': ['Cognitive Science', 'Neuroscience', 'Cognitive Psychology'], 'citedby': 33385, 'citedby5y': 8879, 'hindex': 80, 'hindex5y': 46, 'i10index': 291, 'i10index5y': 186}
# <Record id='leventsagun@gmail.com' name='Levent Sagun'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': '-iPZaBcAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=-iPZaBcAAAAJ', 'name': 'Levent Sagun', 'affiliation': 'FAIR', 'email_domain': '@meta.com', 'interests': ['machine learning', 'deep learning', 'probability', 'statistical physics', 'energy landscapes'], 'citedby': 3830, 'citedby5y': 3519, 'hindex': 17, 'hindex5y': 17, 'i10index': 22, 'i10index5y': 21}
# <Record id='ue225@nyu.edu' name='Utku Evci'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': '8yGMMwcAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=8yGMMwcAAAAJ', 'name': 'Utku Evci', 'affiliation': 'Researcher @Google Brain', 'email_domain': '@nyu.edu', 'interests': ['Machine Learning'], 'citedby': 2018, 'citedby5y': 1978, 'hindex': 12, 'hindex5y': 12, 'i10index': 12, 'i10index5y': 12}
# <Record id='vug@fb.com' name='V. Ugur Guney'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': '3aYVAZEAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=3aYVAZEAAAAJ', 'name': 'V. Uğur Güney', 'affiliation': 'PhD Gruaduate, CUNY Graduate Center, Hunter College', 'email_domain': '@hunter.cuny.edu', 'interests': ['Physics', 'bell theorem', 'fundamentals of quantum mechanics', 'quantum nonlocality', 'quantum contextuality'], 'citedby': 873, 'citedby5y': 739, 'hindex': 6, 'hindex5y': 5, 'i10index': 6, 'i10index5y': 4}
# <Record id='yann@dauphin.io' name='Yann N. Dauphin'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'XSforroAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=XSforroAAAAJ', 'name': 'Yann N. Dauphin', 'affiliation': 'Google AI', 'email_domain': '@dauphin.io', 'interests': ['Machine Learning', 'Artificial Intelligence'], 'citedby': 28580, 'citedby5y': 24284, 'hindex': 38, 'hindex5y': 38, 'i10index': 51, 'i10index5y': 49}
# <Record id='leonb@fb.com' name='Léon Bottou'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'kbN88gsAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=kbN88gsAAAAJ', 'name': 'Leon Bottou', 'affiliation': 'Facebook AI Research', 'email_domain': '@bottou.org', 'interests': ['Machine learning', 'artificial intelligence'], 'citedby': 159356, 'citedby5y': 106418, 'hindex': 86, 'hindex5y': 70, 'i10index': 163, 'i10index5y': 125}
# <Record id='jiaming.tsong@gmail.com' name='Jiaming Song'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': '6dP660cAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=6dP660cAAAAJ', 'name': 'Jiaming Song', 'affiliation': 'Stanford University', 'email_domain': '@cs.stanford.edu', 'interests': ['Machine Learning'], 'citedby': 8842, 'citedby5y': 8538, 'hindex': 34, 'hindex5y': 33, 'i10index': 60, 'i10index5y': 59}
# <Record id='rhy@pku.edu.cn' name='Hongyu Ren'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'cbuy0ocAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=cbuy0ocAAAAJ', 'name': 'Hongyu Ren', 'affiliation': 'OpenAI', 'email_domain': '@openai.com', 'interests': ['Machine Learning'], 'citedby': 7698, 'citedby5y': 7683, 'hindex': 22, 'hindex5y': 22, 'i10index': 28, 'i10index5y': 28}
# <Record id='dorsa@cs.stanford.edu' name='Dorsa Sadigh'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'ZaJEZpYAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=ZaJEZpYAAAAJ', 'name': 'Dorsa Sadigh', 'affiliation': 'Stanford University', 'email_domain': '@cs.stanford.edu', 'interests': ['Robotics', 'Human-Robot Interaction', 'Machine Learning', 'Artificial Intelligence', 'Control Theory'], 'citedby': 9389, 'citedby5y': 8548, 'hindex': 43, 'hindex5y': 40, 'i10index': 105, 'i10index5y': 99}
# <Record id='ermon@cs.stanford.edu' name='Stefano Ermon'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'ogXTOZ4AAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=ogXTOZ4AAAAJ', 'name': 'Stefano Ermon', 'affiliation': 'Stanford University', 'email_domain': '@cs.stanford.edu', 'interests': ['Artificial Intelligence', 'Machine Learning', 'Computational Sustainability'], 'citedby': 39301, 'citedby5y': 37328, 'hindex': 77, 'hindex5y': 76, 'i10index': 223, 'i10index5y': 211}
# ...
# <Record id='jpineau@cs.mcgill.ca' name='Joelle Pineau'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'CEt6_mMAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=CEt6_mMAAAAJ', 'name': 'Joelle Pineau', 'affiliation': 'School of Computer Science, McGill University; FAIR, Meta AI; Mila', 'email_domain': '@cs.mcgill.ca', 'interests': ['Artificial intelligence', 'Machine learning', 'Robotics'], 'citedby': 31686, 'citedby5y': 21855, 'hindex': 74, 'hindex5y': 63, 'i10index': 208, 'i10index5y': 166}
# <Record id='nicolas@le-roux.name' name='Nicolas Le Roux'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'LmKtwk8AAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=LmKtwk8AAAAJ', 'name': 'Nicolas Le Roux', 'affiliation': 'Microsoft Research, McGill, UdeM', 'email_domain': '@le-roux.name', 'interests': ['Machine Learning', 'Neural networks', 'Deep learning', 'Optimization'], 'citedby': 10083, 'citedby5y': 4878, 'hindex': 30, 'hindex5y': 27, 'i10index': 48, 'i10index5y': 43}
# <Record id='rezababa@cs.ubc.ca' name='Reza Babanezhad'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'KLrwPsgAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=KLrwPsgAAAAJ', 'name': 'Reza Babanezhad', 'affiliation': 'Samsung AI lab', 'email_domain': '', 'interests': ['Machine Learning'], 'citedby': 507, 'citedby5y': 357, 'hindex': 8, 'hindex5y': 8, 'i10index': 8, 'i10index5y': 8}
# <Record id='manzagop@google.com' name='Pierre-Antoine Manzagol'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'xdlBKc8AAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=xdlBKc8AAAAJ', 'name': 'Pierre-Antoine Manzagol', 'affiliation': 'Google Brain', 'email_domain': '@google.com', 'interests': [], 'citedby': 24114, 'citedby5y': 14805, 'hindex': 16, 'hindex5y': 15, 'i10index': 17, 'i10index5y': 16}
# <Record id='rinu@cai.fi' name='Rinu Boney'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'A7TgArIAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=A7TgArIAAAAJ', 'name': 'Rinu Boney', 'affiliation': 'Doctoral Candidate, Aalto University', 'email_domain': '@aalto.fi', 'interests': ['deep learning', 'computer vision', 'reinforcement learning'], 'citedby': 229, 'citedby5y': 208, 'hindex': 9, 'hindex5y': 8, 'i10index': 8, 'i10index5y': 7}
# <Record id='alexilin@cai.fi' name='Alexander Ilin'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': '1gb16vIAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=1gb16vIAAAAJ', 'name': 'Aleksandr ilyin', 'affiliation': 'Tomsk Polytechnic University', 'email_domain': '@tpu.ru', 'interests': ['наноматериалы'], 'citedby': 4147, 'citedby5y': 1112, 'hindex': 28, 'hindex5y': 15, 'i10index': 115, 'i10index5y': 32}
# <Record id='victor@erlerobotics.com' name='Víctor Mayoral'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'dWKDuxcAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=dWKDuxcAAAAJ', 'name': 'Victor Martin-Mayor', 'affiliation': 'Professor of theoretical physics (Universidad Complutense de Madrid)', 'email_domain': '@ucm.es', 'interests': ['Statistical Mechanics', 'disordered systems', 'phase transitions', 'Monte Carlo simulations'], 'citedby': 9997, 'citedby5y': 2382, 'hindex': 49, 'hindex5y': 26, 'i10index': 118, 'i10index5y': 66}
# <Record id='risto@erlerobotics.com' name='Risto Kojcev'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'jxPZBYYAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=jxPZBYYAAAAJ', 'name': 'Risto Kojcev', 'affiliation': 'Johnson and Johnson', 'email_domain': '@its.jnj.com', 'interests': ['Robotics', 'Artificial Intelligence', 'Computer Vision', 'Reinforcement Learning'], 'citedby': 581, 'citedby5y': 488, 'hindex': 10, 'hindex5y': 10, 'i10index': 12, 'i10index5y': 10}
# <Record id='nora@erlerobotics.com' name='Nora Etxezarreta'>
# author not found on gscholar
# <Record id='alex@erlerobotics.com' name='Alejandro Hernández'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'zIawCusAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=zIawCusAAAAJ', 'name': 'ALEXANDER VLADIMIR CLAROS HERNANDEZ', 'affiliation': 'estudiante', 'email_domain': '@prepauvm.com.mx', 'interests': ['informatica'], 'citedby': 79294, 'citedby5y': 49408, 'hindex': 131, 'hindex5y': 98, 'i10index': 694, 'i10index5y': 606}
# <Record id='irati@erlerobotics.com' name='Irati Zamalloa'>
# author not found on gscholar
# <Record id='yw4@andrew.cmu.edu' name='Yifan Wu'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': '7am85F0AAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=7am85F0AAAAJ', 'name': 'Yifan Wu', 'affiliation': 'University of Washington', 'email_domain': '@uw.edu', 'interests': [], 'citedby': 1416, 'citedby5y': 1329, 'hindex': 11, 'hindex5y': 10, 'i10index': 11, 'i10index5y': 10}
# <Record id='bapoczos@cs.cmu.edu' name='Barnabás Póczos'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'sUriZlUAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=sUriZlUAAAAJ', 'name': 'Barnabas Poczos', 'affiliation': 'Associate professor, Carnegie Mellon University', 'email_domain': '@cs.cmu.edu', 'interests': ['Artificial Intelligence', 'Machine Learning', 'Statistics'], 'citedby': 18611, 'citedby5y': 15445, 'hindex': 68, 'hindex5y': 60, 'i10index': 158, 'i10index5y': 124}
# <Record id='aarti@cs.cmu.edu' name='Aarti Singh'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'VIuLJjIAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=VIuLJjIAAAAJ', 'name': 'aarti Singh', 'affiliation': '', 'email_domain': '', 'interests': ['art and craft'], 'citedby': 12654, 'citedby5y': 7375, 'hindex': 54, 'hindex5y': 40, 'i10index': 242, 'i10index5y': 148}
# <Record id='bordaw@us.ibm.com' name='Rajesh Bordawekar'>
# found with name and domain.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'mQMC3aYAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=mQMC3aYAAAAJ', 'name': 'Rajesh Bordawekar', 'affiliation': 'IBM TJ Watson Research Center', 'email_domain': '@us.ibm.com', 'interests': ['Parallel Computing', 'Analytics', 'Algorithms'], 'citedby': 4749, 'citedby5y': 871, 'hindex': 39, 'hindex5y': 19, 'i10index': 82, 'i10index5y': 26}
# <Record id='oshmu@cs.technion.ac.il' name='Oded Shmueli'>
# author not found on gscholar
# <Record id='bandyopadhyay.14@osu.edu' name='Bortik Bandyopadhyay'>
# author not found on gscholar
# <Record id='jxwuyi@gmail.com' name='Yi Wu†'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': '0RVGObQAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=0RVGObQAAAAJ', 'name': 'Yi-long Wu', 'affiliation': "Professor of Oncology, Guangdong Lung Cancer Institute, Guangdong Provincial People's …", 'email_domain': '@gdph.org.cn', 'interests': ['Lung Cancer'], 'citedby': 93647, 'citedby5y': 53588, 'hindex': 115, 'hindex5y': 97, 'i10index': 454, 'i10index5y': 366}
# <Record id='ppwwyyxxc@gmail.com' name='Yuxin Wu'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'mJQI-gUAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=mJQI-gUAAAAJ', 'name': 'Yuxin Wu', 'affiliation': '', 'email_domain': '@google.com', 'interests': ['Computer Vision', 'Machine Learning'], 'citedby': 22267, 'citedby5y': 21540, 'hindex': 16, 'hindex5y': 16, 'i10index': 16, 'i10index5y': 16}
# <Record id='georgia.gkioxari@gmail.com' name='Georgia Gkioxari'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'kQisE-gAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=kQisE-gAAAAJ', 'name': 'Georgia Gkioxari', 'affiliation': 'Caltech', 'email_domain': '@caltech.edu', 'interests': ['Computer Vision', 'Machine Learning', 'Artificial Intelligence'], 'citedby': 41228, 'citedby5y': 38324, 'hindex': 31, 'hindex5y': 31, 'i10index': 36, 'i10index5y': 36}
# <Record id='yuandong.tian@gmail.com' name='Yuandong Tian'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': '0mgEF28AAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=0mgEF28AAAAJ', 'name': 'Yuandong Tian', 'affiliation': 'Research Scientist, Meta AI (FAIR)', 'email_domain': '@fb.com', 'interests': ['Reinforcement Learning', 'Search and Optimization', 'Representation Learning'], 'citedby': 9774, 'citedby5y': 8247, 'hindex': 50, 'hindex5y': 46, 'i10index': 88, 'i10index5y': 80}
# <Record id='devansharpit@gmail.com' name='Devansh Arpit'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'oU0jQIAAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=oU0jQIAAAAAJ', 'name': 'Devansh Arpit', 'affiliation': 'Rashi.ai', 'email_domain': '@rashi.ai', 'interests': ['Deep Learning', 'NLP'], 'citedby': 4572, 'citedby5y': 4230, 'hindex': 21, 'hindex5y': 21, 'i10index': 27, 'i10index5y': 23}
# <Record id='ashaanoosheh@aol.com' name='Asha Anoosheh'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'c1ydkqUAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=c1ydkqUAAAAJ', 'name': 'Asha Anoosheh', 'affiliation': 'NNAISENSE', 'email_domain': '@nnaisense.com', 'interests': ['computer vision'], 'citedby': 592, 'citedby5y': 571, 'hindex': 5, 'hindex5y': 5, 'i10index': 4, 'i10index5y': 4}
# <Record id='etagust@gmail.com' name='Eirikur Agustsson'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'Uhvyua4AAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=Uhvyua4AAAAJ', 'name': 'Eirikur Agustsson', 'affiliation': 'Research Scientist @ Google', 'email_domain': '@google.com', 'interests': [], 'citedby': 8821, 'citedby5y': 8408, 'hindex': 24, 'hindex5y': 24, 'i10index': 30, 'i10index5y': 28}
# <Record id='radu.timofte@ethz.ch' name='Radu Timofte'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'u3MwH5kAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=u3MwH5kAAAAJ', 'name': 'Radu Timofte', 'affiliation': 'Humboldt Professor for AI and Computer Vision, University of Würzburg', 'email_domain': '@uni-wuerzburg.de', 'interests': ['Computer Vision', 'Machine Learning', 'AI', 'Compression', 'Computational Photography'], 'citedby': 40571, 'citedby5y': 35039, 'hindex': 86, 'hindex5y': 84, 'i10index': 285, 'i10index5y': 265}
# <Record id='a88575847@gmail.com' name='Hui-Po Wang'>
# found with name.
# {'container_type': 'Author', 'filled': ['indices'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'UAnfs8UAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=UAnfs8UAAAAJ', 'name': 'Hui-Po Wang (王暉博)', 'affiliation': 'Ph.D. student, CISPA-Helmholtz Center for Information Security', 'email_domain': '@cispa.saarland', 'interests': ['trustworthy machine learning', 'generative models', 'federated learning'], 'citedby': 387, 'citedby5y': 387, 'hindex': 7, 'hindex5y': 7, 'i10index': 6, 'i10index5y': 6}
# <Record id='ts771164@gmail.com' name='Wei-Jan Ko'>
# ---------------------------------------------------------------------------
# MaxTriesExceededException                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 main()
#
# Cell In[11], line 6, in main()
#       4 for author in author_batch:
#       5     print(author)
# ----> 6     info = find_author_info_gscholar(author["id"], author["name"])
#       7     if info is not None:
#       8         set_author_gscholar_info(author["id"], info)
#
# Cell In[10], line 25, in find_author_info_gscholar(id, name)
#      23 # Retrieve the first result from the iterator
#      24 try:
# ---> 25     first_author_result = next(search_query)
#      26     print("found with name and domain.")
#      27 except StopIteration:
#
# File ~/work/projects/conference-simulation/data/crawling_or_env/lib/python3.11/site-packages/scholarly/_navigator.py:250, in Navigator.search_authors(self, url)
#     248 def search_authors(self, url: str)->Author:
#     249     """Generator that returns Author objects from the author search page"""
# --> 250     soup = self._get_soup(url)
#     252     author_parser = AuthorParser(self)
#     253     while True:
#
# File ~/work/projects/conference-simulation/data/crawling_or_env/lib/python3.11/site-packages/scholarly/_navigator.py:239, in Navigator._get_soup(self, url)
#     237 def _get_soup(self, url: str) -> BeautifulSoup:
#     238     """Return the BeautifulSoup for a page on scholar.google.com"""
# --> 239     html = self._get_page('https://scholar.google.com{0}'.format(url))
#     240     html = html.replace(u'\xa0', u' ')
#     241     res = BeautifulSoup(html, 'html.parser')
#
# File ~/work/projects/conference-simulation/data/crawling_or_env/lib/python3.11/site-packages/scholarly/_navigator.py:188, in Navigator._get_page(self, pagerequest, premium)
#     186 # If secondary proxy does not work, try again primary proxy.
#     187 if not premium:
# --> 188     return self._get_page(pagerequest, True)
#     189 else:
#     190     raise MaxTriesExceededException("Cannot Fetch from Google Scholar.")
#
# File ~/work/projects/conference-simulation/data/crawling_or_env/lib/python3.11/site-packages/scholarly/_navigator.py:190, in Navigator._get_page(self, pagerequest, premium)
#     188     return self._get_page(pagerequest, True)
#     189 else:
# --> 190     raise MaxTriesExceededException("Cannot Fetch from Google Scholar.")
#
# MaxTriesExceededException: Cannot Fetch from Google Scholar.
