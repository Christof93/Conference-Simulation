# %%
import numpy as np
from env.reputation_environment import ReputationEnvironment
from env.evaluator import EnvironmentRecorder, NetworkEvaluator

# %%
from custom_policies import *

# %%
def run_experiment(num_runs, env_hyperparameters, strategy_probs):
    for _ in range(num_runs):
        env = ReputationEnvironment(**env_hyperparameters)
        # env = ReputationEnvironment(n_authors=10, n_conferences=1, render_mode="all", max_rewardless_steps=150, max_agent_steps=5000, max_coauthors=10)
        recorder = EnvironmentRecorder(env)
        observations, infos = env.reset()
        agent_to_strategy = {}
        strats, probs = zip(*strategy_probs.items())
        for agent in env.agents:
            agent_to_strategy[agent] = np.random.choice(list(strats), p=probs)
        recorder.agent_to_strategy = agent_to_strategy

        while len(env.agents) > 0:
            # this is where you would insert your policy
            actions = {}
            for agent in env.agents:
                if agent_to_strategy[agent] == "honest":
                    actions[agent] = simple_policy(agent, env)
                elif agent_to_strategy[agent] == "malicious":
                    actions[agent] = malicious_policy(agent, env)
                elif agent_to_strategy[agent] == "diligent":
                    actions[agent] = diligent_policy(agent, env)
                else:
                    actions[agent] = random_policy(agent, env)
            observations, rewards, terminations, truncations, infos = env.step(actions)
            # breakpoint()
            # env.render()
            # sleep(0.5)
            if env.timestep > 1000:
                break

        if env.render_mode == "network":
            evaluator = NetworkEvaluator(
                {
                    "nodes": list(env.network_nodes.values()), 
                    "links": env.network_links,
                    "steps": env.timestep,
                    "initial_reputation": env.initial_reputation,
                    "agent_strategy": agent_to_strategy,
                    "remaining_agents": env.agents
                }
            )
            evaluator.report()
        else:
            recorder.report()
        # env.render()
        env.close

# %%
params1 = {
    "n_authors":500,
    "n_conferences":10,
    "render_mode":"network",
    "max_rewardless_steps":150,
    "max_agent_steps":5000, 
    "max_coauthors":10
}
strats = {
    "diligent": 1,
    "honest": 0,
    "malicious":0
}
run_experiment(5, params1, strats)

# %%
params1 = {
    "n_authors":500,
    "n_conferences":10,
    "render_mode":"network",
    "max_rewardless_steps":150,
    "max_agent_steps":5000, 
    "max_coauthors":10
}
strats = {
    "diligent": 1,
    "honest": 0,
    "malicious":0
}
run_experiment(5, params1, strats)
# Out:
# Analysis from network file
# --------------------
# simulation with 500 authors went on for 1001 steps.
# 424 agents remain.
# number of papers submitted: 8032
# number of papers accepted: 4166
# average number of coauthors per author: 3.08
# Agent strategies:
#   - before: diligent: 1.0
#   - after: diligent: 1.00
# mean reputation increase: 43.568
# mean effort put into submitted papers: 52.45
# median effort put into submitted papers: 52.00
# conference submissions, publications and acceptance rates:
#  - conference_0_0 (reputation: 400):   51/60   (0.85)
#  - conference_1_0 (reputation: 450):   51/82   (0.62)
#  - conference_2_0 (reputation: 450):   51/74   (0.69)
#  - conference_3_0 (reputation: 450):   51/79   (0.65)
#  - conference_4_0 (reputation: 500):   51/152  (0.34)
#  - conference_5_0 (reputation: 400):   50/60   (0.83)
#  - conference_6_0 (reputation: 400):   50/53   (0.94)
#  - conference_7_0 (reputation: 500):   50/160  (0.31)
#  - conference_8_0 (reputation: 500):   50/155  (0.32)
#  - conference_9_0 (reputation: 400):   50/57   (0.88)
#  - conference_6_1 (reputation: 500):   50/155  (0.32)
#  - conference_0_1 (reputation: 500):   50/164  (0.30)
#  - conference_5_1 (reputation: 500):   50/112  (0.45)
#  - conference_9_1 (reputation: 500):   50/184  (0.27)
#  - conference_1_1 (reputation: 400):   51/57   (0.89)
#  - conference_3_1 (reputation: 500):   50/155  (0.32)
#  - conference_2_1 (reputation: 400):   51/57   (0.89)
#  - conference_1_2 (reputation: 450):   50/74   (0.68)
#  - conference_4_1 (reputation: 500):   50/156  (0.32)
#  - conference_2_2 (reputation: 400):   51/65   (0.78)
#  - conference_8_1 (reputation: 450):   50/81   (0.62)
#  - conference_7_1 (reputation: 500):   50/167  (0.30)
#  - conference_1_3 (reputation: 400):   51/64   (0.80)
#  - conference_5_2 (reputation: 500):   50/141  (0.35)
#  - conference_2_3 (reputation: 450):   51/92   (0.55)
#  - conference_6_2 (reputation: 500):   50/125  (0.40)
#  - conference_0_2 (reputation: 450):   50/77   (0.65)
#  - conference_3_2 (reputation: 400):   51/64   (0.80)
#  - conference_8_2 (reputation: 500):   50/133  (0.38)
#  - conference_1_4 (reputation: 450):   51/71   (0.72)
#  - conference_9_2 (reputation: 450):   50/75   (0.67)
#  - conference_3_3 (reputation: 400):   50/53   (0.94)
#  - conference_0_3 (reputation: 400):   50/63   (0.79)
#  - conference_2_4 (reputation: 500):   51/147  (0.35)
#  - conference_4_2 (reputation: 500):   50/146  (0.34)
#  - conference_3_4 (reputation: 500):   50/138  (0.36)
#  - conference_1_5 (reputation: 500):   50/172  (0.29)
#  - conference_9_3 (reputation: 450):   50/84   (0.60)
#  - conference_5_3 (reputation: 450):   51/71   (0.72)
#  - conference_6_3 (reputation: 450):   50/73   (0.68)
#  - conference_7_2 (reputation: 450):   50/84   (0.60)
#  - conference_8_3 (reputation: 500):   50/163  (0.31)
#  - conference_0_4 (reputation: 400):   52/63   (0.83)
#  - conference_5_4 (reputation: 400):   50/58   (0.86)
#  - conference_9_4 (reputation: 450):   50/79   (0.63)
#  - conference_6_4 (reputation: 450):   50/75   (0.67)
#  - conference_0_5 (reputation: 450):   50/84   (0.60)
#  - conference_7_3 (reputation: 450):   50/72   (0.69)
#  - conference_2_5 (reputation: 400):   50/55   (0.91)
#  - conference_5_5 (reputation: 500):   50/142  (0.35)
#  - conference_3_5 (reputation: 400):   50/63   (0.79)
#  - conference_4_3 (reputation: 400):   50/61   (0.82)
#  - conference_9_5 (reputation: 500):   50/150  (0.33)
#  - conference_1_6 (reputation: 450):   51/87   (0.59)
#  - conference_6_5 (reputation: 500):   50/153  (0.33)
#  - conference_2_6 (reputation: 450):   50/91   (0.55)
#  - conference_4_4 (reputation: 500):   50/148  (0.34)
#  - conference_8_4 (reputation: 400):   50/57   (0.88)
#  - conference_3_6 (reputation: 450):   50/73   (0.68)
#  - conference_7_4 (reputation: 500):   51/168  (0.30)
#  - conference_0_6 (reputation: 450):   50/85   (0.59)
#  - conference_8_5 (reputation: 450):   51/68   (0.75)
#  - conference_1_7 (reputation: 400):   50/60   (0.83)
#  - conference_5_6 (reputation: 500):   50/167  (0.30)
#  - conference_3_7 (reputation: 500):   51/125  (0.41)
#  - conference_2_7 (reputation: 450):   50/80   (0.62)
#  - conference_9_6 (reputation: 500):   50/178  (0.28)
#  - conference_0_7 (reputation: 450):   50/72   (0.69)
#  - conference_1_8 (reputation: 500):   50/162  (0.31)
#  - conference_8_6 (reputation: 400):   51/63   (0.81)
#  - conference_6_6 (reputation: 400):   51/59   (0.86)
#  - conference_4_5 (reputation: 400):   50/57   (0.88)
#  - conference_2_8 (reputation: 400):   51/54   (0.94)
#  - conference_7_5 (reputation: 400):   50/62   (0.81)
#  - conference_0_8 (reputation: 400):   51/63   (0.81)
#  - conference_8_7 (reputation: 400):   50/60   (0.83)
#  - conference_3_8 (reputation: 400):   50/65   (0.77)
#  - conference_2_9 (reputation: 450):   44/78   (0.56)
#  - conference_4_6 (reputation: 400):   51/60   (0.85)
#  - conference_6_7 (reputation: 450):   32/55   (0.58)
#  - conference_0_9 (reputation: 450):   32/54   (0.59)
#  - conference_7_6 (reputation: 400):   46/50   (0.92)
#  - conference_5_7 (reputation: 400):   30/33   (0.91)
#  - conference_8_8 (reputation: 500):   12/43   (0.28)
#  - conference_9_7 (reputation: 500):    8/34   (0.24)
#  - conference_4_7 (reputation: 450):   20/30   (0.67)
#  - conference_3_9 (reputation: 500):   10/34   (0.29)
#  - conference_1_9 (reputation: 400):    7/7    (1.00)
#
# Analysis from network file
# --------------------
# simulation with 500 authors went on for 1001 steps.
# 401 agents remain.
# number of papers submitted: 7693
# number of papers accepted: 3988
# average number of coauthors per author: 3.08
# Agent strategies:
#   - before: diligent: 1.0
#   - after: diligent: 1.00
# mean reputation increase: 41.73
# mean effort put into submitted papers: 52.48
# median effort put into submitted papers: 52.00
# conference submissions, publications and acceptance rates:
#  - conference_0_0 (reputation: 450):   51/72   (0.71)
#  - conference_1_0 (reputation: 450):   51/82   (0.62)
#  - conference_2_0 (reputation: 450):   50/68   (0.74)
#  - conference_3_0 (reputation: 450):   50/75   (0.67)
#  - conference_4_0 (reputation: 500):   50/167  (0.30)
#  - conference_5_0 (reputation: 400):   50/56   (0.89)
#  - conference_6_0 (reputation: 500):   50/120  (0.42)
#  - conference_7_0 (reputation: 400):   51/58   (0.88)
#  - conference_8_0 (reputation: 500):   50/151  (0.33)
#  - conference_9_0 (reputation: 450):   50/82   (0.61)
#  - conference_5_1 (reputation: 450):   50/79   (0.63)
#  - conference_7_1 (reputation: 500):   50/140  (0.36)
#  - conference_2_1 (reputation: 500):   50/156  (0.32)
#  - conference_3_1 (reputation: 400):   50/58   (0.86)
#  - conference_9_1 (reputation: 400):   50/54   (0.93)
#  - conference_0_1 (reputation: 500):   50/140  (0.36)
#  - conference_1_1 (reputation: 500):   51/135  (0.38)
#  - conference_6_1 (reputation: 500):   50/144  (0.35)
#  - conference_5_2 (reputation: 500):   50/155  (0.32)
#  - conference_9_2 (reputation: 450):   50/95   (0.53)
#  - conference_3_2 (reputation: 500):   50/151  (0.33)
#  - conference_8_1 (reputation: 400):   50/57   (0.88)
#  - conference_4_1 (reputation: 500):   50/136  (0.37)
#  - conference_7_2 (reputation: 500):   50/145  (0.34)
#  - conference_2_2 (reputation: 500):   50/156  (0.32)
#  - conference_8_2 (reputation: 450):   51/88   (0.58)
#  - conference_9_3 (reputation: 400):   50/61   (0.82)
#  - conference_0_2 (reputation: 500):   50/118  (0.42)
#  - conference_6_2 (reputation: 400):   50/59   (0.85)
#  - conference_1_2 (reputation: 450):   50/77   (0.65)
#  - conference_3_3 (reputation: 500):   50/175  (0.29)
#  - conference_9_4 (reputation: 400):   51/66   (0.77)
#  - conference_6_3 (reputation: 400):   51/64   (0.80)
#  - conference_4_2 (reputation: 400):   51/58   (0.88)
#  - conference_8_3 (reputation: 450):   51/79   (0.65)
#  - conference_5_3 (reputation: 400):   51/62   (0.82)
#  - conference_1_3 (reputation: 400):   51/61   (0.84)
#  - conference_7_3 (reputation: 500):   50/138  (0.36)
#  - conference_9_5 (reputation: 450):   50/72   (0.69)
#  - conference_0_3 (reputation: 450):   50/72   (0.69)
#  - conference_4_3 (reputation: 400):   51/58   (0.88)
#  - conference_2_3 (reputation: 500):   50/163  (0.31)
#  - conference_1_4 (reputation: 400):   50/56   (0.89)
#  - conference_6_4 (reputation: 450):   50/78   (0.64)
#  - conference_5_4 (reputation: 450):   50/72   (0.69)
#  - conference_8_4 (reputation: 400):   51/58   (0.88)
#  - conference_9_6 (reputation: 450):   50/73   (0.68)
#  - conference_1_5 (reputation: 500):   50/158  (0.32)
#  - conference_4_4 (reputation: 450):   50/94   (0.53)
#  - conference_0_4 (reputation: 500):   50/183  (0.27)
#  - conference_6_5 (reputation: 500):   51/153  (0.33)
#  - conference_8_5 (reputation: 450):   50/73   (0.68)
#  - conference_3_4 (reputation: 500):   50/167  (0.30)
#  - conference_5_5 (reputation: 400):   50/59   (0.85)
#  - conference_7_4 (reputation: 400):   53/65   (0.82)
#  - conference_9_7 (reputation: 500):   50/178  (0.28)
#  - conference_5_6 (reputation: 450):   50/76   (0.66)
#  - conference_4_5 (reputation: 450):   50/64   (0.78)
#  - conference_2_4 (reputation: 450):   51/93   (0.55)
#  - conference_7_5 (reputation: 450):   50/78   (0.64)
#  - conference_8_6 (reputation: 400):   51/63   (0.81)
#  - conference_5_7 (reputation: 400):   51/60   (0.85)
#  - conference_1_6 (reputation: 450):   50/74   (0.68)
#  - conference_4_6 (reputation: 400):   51/60   (0.85)
#  - conference_6_6 (reputation: 400):   50/60   (0.83)
#  - conference_0_5 (reputation: 400):   52/59   (0.88)
#  - conference_8_7 (reputation: 450):   51/77   (0.66)
#  - conference_3_5 (reputation: 400):   50/58   (0.86)
#  - conference_2_5 (reputation: 500):   47/154  (0.31)
#  - conference_7_6 (reputation: 450):   50/71   (0.70)
#  - conference_5_8 (reputation: 450):   50/77   (0.65)
#  - conference_6_7 (reputation: 500):   50/138  (0.36)
#  - conference_1_7 (reputation: 500):   50/113  (0.44)
#  - conference_0_6 (reputation: 450):   50/83   (0.60)
#  - conference_4_7 (reputation: 450):   50/78   (0.64)
#  - conference_9_8 (reputation: 500):   42/100  (0.42)
#  - conference_8_8 (reputation: 500):   29/87   (0.33)
#  - conference_3_6 (reputation: 400):   50/58   (0.86)
#  - conference_7_7 (reputation: 500):   25/85   (0.29)
#  - conference_5_9 (reputation: 500):   19/72   (0.26)
#  - conference_4_8 (reputation: 450):   22/38   (0.58)
#  - conference_0_7 (reputation: 450):   13/22   (0.59)
#  - conference_3_7 (reputation: 450):   10/16   (0.62)
#  - conference_1_8 (reputation: 400):    4/5    (0.80)
#  - conference_6_8 (reputation: 400):    3/4    (0.75)
#
# Analysis from network file
# --------------------
# simulation with 500 authors went on for 1001 steps.
# 433 agents remain.
# number of papers submitted: 8287
# number of papers accepted: 4347
# average number of coauthors per author: 3.07
# Agent strategies:
#   - before: diligent: 1.0
#   - after: diligent: 1.00
# mean reputation increase: 45.344
# mean effort put into submitted papers: 52.48
# median effort put into submitted papers: 52.00
# conference submissions, publications and acceptance rates:
#  - conference_0_0 (reputation: 400):   50/57   (0.88)
#  - conference_1_0 (reputation: 500):   50/125  (0.40)
#  - conference_2_0 (reputation: 400):   50/57   (0.88)
#  - conference_3_0 (reputation: 400):   50/63   (0.79)
#  - conference_4_0 (reputation: 500):   50/136  (0.37)
#  - conference_5_0 (reputation: 450):   50/91   (0.55)
#  - conference_6_0 (reputation: 400):   51/63   (0.81)
#  - conference_7_0 (reputation: 500):   50/111  (0.45)
#  - conference_8_0 (reputation: 500):   50/138  (0.36)
#  - conference_9_0 (reputation: 400):   50/62   (0.81)
#  - conference_0_1 (reputation: 450):   51/80   (0.64)
#  - conference_2_1 (reputation: 450):   50/92   (0.54)
#  - conference_9_1 (reputation: 400):   50/62   (0.81)
#  - conference_6_1 (reputation: 450):   50/83   (0.60)
#  - conference_3_1 (reputation: 400):   53/59   (0.90)
#  - conference_5_1 (reputation: 400):   50/60   (0.83)
#  - conference_9_2 (reputation: 500):   50/128  (0.39)
#  - conference_7_1 (reputation: 450):   51/89   (0.57)
#  - conference_4_1 (reputation: 400):   50/60   (0.83)
#  - conference_1_1 (reputation: 500):   50/143  (0.35)
#  - conference_8_1 (reputation: 450):   50/96   (0.52)
#  - conference_3_2 (reputation: 500):   50/145  (0.34)
#  - conference_6_2 (reputation: 400):   50/54   (0.93)
#  - conference_0_2 (reputation: 500):   50/175  (0.29)
#  - conference_2_2 (reputation: 500):   50/145  (0.34)
#  - conference_5_2 (reputation: 500):   50/176  (0.28)
#  - conference_7_2 (reputation: 500):   50/196  (0.26)
#  - conference_4_2 (reputation: 450):   50/74   (0.68)
#  - conference_6_3 (reputation: 500):   50/166  (0.30)
#  - conference_8_2 (reputation: 400):   51/64   (0.80)
#  - conference_9_3 (reputation: 500):   50/139  (0.36)
#  - conference_3_3 (reputation: 500):   50/147  (0.34)
#  - conference_8_3 (reputation: 450):   50/76   (0.66)
#  - conference_4_3 (reputation: 400):   50/59   (0.85)
#  - conference_0_3 (reputation: 450):   50/92   (0.54)
#  - conference_1_2 (reputation: 400):   50/61   (0.82)
#  - conference_2_3 (reputation: 500):   50/164  (0.30)
#  - conference_5_3 (reputation: 400):   51/58   (0.88)
#  - conference_8_4 (reputation: 500):   50/141  (0.35)
#  - conference_4_4 (reputation: 500):   51/141  (0.36)
#  - conference_1_3 (reputation: 400):   50/59   (0.85)
#  - conference_0_4 (reputation: 500):   50/168  (0.30)
#  - conference_5_4 (reputation: 500):   50/160  (0.31)
#  - conference_1_4 (reputation: 400):   51/59   (0.86)
#  - conference_7_3 (reputation: 400):   50/58   (0.86)
#  - conference_6_4 (reputation: 500):   51/130  (0.39)
#  - conference_9_4 (reputation: 450):   50/72   (0.69)
#  - conference_3_4 (reputation: 400):   51/58   (0.88)
#  - conference_7_4 (reputation: 450):   50/77   (0.65)
#  - conference_3_5 (reputation: 450):   50/83   (0.60)
#  - conference_1_5 (reputation: 450):   50/71   (0.70)
#  - conference_9_5 (reputation: 400):   51/60   (0.85)
#  - conference_2_4 (reputation: 500):   51/151  (0.34)
#  - conference_8_5 (reputation: 400):   50/58   (0.86)
#  - conference_4_5 (reputation: 400):   50/60   (0.83)
#  - conference_6_5 (reputation: 500):   50/156  (0.32)
#  - conference_7_5 (reputation: 400):   51/65   (0.78)
#  - conference_1_6 (reputation: 450):   50/78   (0.64)
#  - conference_9_6 (reputation: 450):   50/75   (0.67)
#  - conference_3_6 (reputation: 400):   50/57   (0.88)
#  - conference_5_5 (reputation: 450):   50/81   (0.62)
#  - conference_0_5 (reputation: 450):   50/94   (0.53)
#  - conference_8_6 (reputation: 450):   50/73   (0.68)
#  - conference_4_6 (reputation: 450):   50/85   (0.59)
#  - conference_3_7 (reputation: 400):   50/60   (0.83)
#  - conference_7_6 (reputation: 500):   50/155  (0.32)
#  - conference_9_7 (reputation: 500):   50/155  (0.32)
#  - conference_1_7 (reputation: 400):   51/61   (0.84)
#  - conference_5_6 (reputation: 450):   50/93   (0.54)
#  - conference_2_5 (reputation: 400):   51/56   (0.91)
#  - conference_8_7 (reputation: 450):   50/76   (0.66)
#  - conference_0_6 (reputation: 450):   50/83   (0.60)
#  - conference_4_7 (reputation: 450):   50/92   (0.54)
#  - conference_3_8 (reputation: 450):   50/73   (0.68)
#  - conference_1_8 (reputation: 400):   50/57   (0.88)
#  - conference_2_6 (reputation: 450):   50/74   (0.68)
#  - conference_6_6 (reputation: 400):   51/57   (0.89)
#  - conference_8_8 (reputation: 500):   42/117  (0.36)
#  - conference_5_7 (reputation: 500):   41/114  (0.36)
#  - conference_1_9 (reputation: 500):   36/100  (0.36)
#  - conference_6_7 (reputation: 500):   24/98   (0.24)
#  - conference_3_9 (reputation: 500):   33/105  (0.31)
#  - conference_0_7 (reputation: 400):   51/65   (0.78)
#  - conference_2_7 (reputation: 450):   50/74   (0.68)
#  - conference_4_8 (reputation: 400):   50/59   (0.85)
#  - conference_9_8 (reputation: 450):   46/76   (0.61)
#  - conference_7_7 (reputation: 450):   46/76   (0.61)
#  - conference_0_8 (reputation: 450):   22/44   (0.50)
#  - conference_4_9 (reputation: 450):   27/39   (0.69)
#  - conference_2_8 (reputation: 400):   11/12   (0.92)
#
# Analysis from network file
# --------------------
# simulation with 500 authors went on for 1001 steps.
# 440 agents remain.
# number of papers submitted: 8304
# number of papers accepted: 4457
# average number of coauthors per author: 3.07
# Agent strategies:
#   - before: diligent: 1.0
#   - after: diligent: 1.00
# mean reputation increase: 46.316
# mean effort put into submitted papers: 52.48
# median effort put into submitted papers: 52.00
# conference submissions, publications and acceptance rates:
#  - conference_0_0 (reputation: 400):   51/60   (0.85)
#  - conference_1_0 (reputation: 450):   50/82   (0.61)
#  - conference_2_0 (reputation: 450):   50/72   (0.69)
#  - conference_3_0 (reputation: 500):   50/131  (0.38)
#  - conference_4_0 (reputation: 400):   50/54   (0.93)
#  - conference_5_0 (reputation: 500):   50/119  (0.42)
#  - conference_6_0 (reputation: 500):   50/165  (0.30)
#  - conference_7_0 (reputation: 500):   50/172  (0.29)
#  - conference_8_0 (reputation: 500):   50/148  (0.34)
#  - conference_9_0 (reputation: 400):   50/52   (0.96)
#  - conference_9_1 (reputation: 450):   51/79   (0.65)
#  - conference_0_1 (reputation: 500):   51/158  (0.32)
#  - conference_4_1 (reputation: 450):   50/72   (0.69)
#  - conference_2_1 (reputation: 500):   50/104  (0.48)
#  - conference_1_1 (reputation: 400):   50/54   (0.93)
#  - conference_5_1 (reputation: 400):   51/66   (0.77)
#  - conference_1_2 (reputation: 450):   50/78   (0.64)
#  - conference_3_1 (reputation: 400):   51/63   (0.81)
#  - conference_4_2 (reputation: 450):   51/79   (0.65)
#  - conference_9_2 (reputation: 400):   51/54   (0.94)
#  - conference_2_2 (reputation: 500):   50/144  (0.35)
#  - conference_6_1 (reputation: 450):   50/87   (0.57)
#  - conference_8_1 (reputation: 500):   50/188  (0.27)
#  - conference_7_1 (reputation: 400):   50/59   (0.85)
#  - conference_3_2 (reputation: 500):   50/150  (0.33)
#  - conference_5_2 (reputation: 450):   50/80   (0.62)
#  - conference_9_3 (reputation: 450):   50/75   (0.67)
#  - conference_1_3 (reputation: 500):   51/178  (0.29)
#  - conference_4_3 (reputation: 450):   51/77   (0.66)
#  - conference_0_2 (reputation: 450):   50/80   (0.62)
#  - conference_7_2 (reputation: 450):   50/83   (0.60)
#  - conference_6_2 (reputation: 500):   50/118  (0.42)
#  - conference_5_3 (reputation: 500):   50/131  (0.38)
#  - conference_9_4 (reputation: 400):   50/56   (0.89)
#  - conference_4_4 (reputation: 400):   50/63   (0.79)
#  - conference_0_3 (reputation: 400):   50/63   (0.79)
#  - conference_7_3 (reputation: 500):   50/157  (0.32)
#  - conference_2_3 (reputation: 500):   50/155  (0.32)
#  - conference_3_3 (reputation: 400):   50/61   (0.82)
#  - conference_9_5 (reputation: 400):   50/67   (0.75)
#  - conference_1_4 (reputation: 400):   52/63   (0.83)
#  - conference_0_4 (reputation: 450):   50/74   (0.68)
#  - conference_8_2 (reputation: 450):   50/74   (0.68)
#  - conference_4_5 (reputation: 400):   50/61   (0.82)
#  - conference_3_4 (reputation: 450):   50/80   (0.62)
#  - conference_5_4 (reputation: 500):   52/147  (0.35)
#  - conference_6_3 (reputation: 400):   50/57   (0.88)
#  - conference_9_6 (reputation: 400):   51/62   (0.82)
#  - conference_8_3 (reputation: 450):   50/70   (0.71)
#  - conference_4_6 (reputation: 500):   50/223  (0.22)
#  - conference_1_5 (reputation: 400):   50/62   (0.81)
#  - conference_0_5 (reputation: 400):   50/58   (0.86)
#  - conference_6_4 (reputation: 450):   50/69   (0.72)
#  - conference_3_5 (reputation: 450):   50/95   (0.53)
#  - conference_8_4 (reputation: 450):   50/78   (0.64)
#  - conference_1_6 (reputation: 400):   50/59   (0.85)
#  - conference_0_6 (reputation: 500):   50/163  (0.31)
#  - conference_7_4 (reputation: 400):   50/59   (0.85)
#  - conference_9_7 (reputation: 450):   50/86   (0.58)
#  - conference_2_4 (reputation: 500):   51/148  (0.34)
#  - conference_6_5 (reputation: 450):   51/74   (0.69)
#  - conference_1_7 (reputation: 500):   52/136  (0.38)
#  - conference_5_5 (reputation: 500):   50/156  (0.32)
#  - conference_7_5 (reputation: 400):   50/61   (0.82)
#  - conference_8_5 (reputation: 400):   50/59   (0.85)
#  - conference_3_6 (reputation: 500):   51/134  (0.38)
#  - conference_9_8 (reputation: 500):   50/127  (0.39)
#  - conference_6_6 (reputation: 400):   50/56   (0.89)
#  - conference_7_6 (reputation: 450):   51/81   (0.63)
#  - conference_2_5 (reputation: 400):   50/56   (0.89)
#  - conference_8_6 (reputation: 400):   50/59   (0.85)
#  - conference_4_7 (reputation: 450):   50/83   (0.60)
#  - conference_6_7 (reputation: 400):   50/58   (0.86)
#  - conference_0_7 (reputation: 450):   50/78   (0.64)
#  - conference_1_8 (reputation: 450):   50/69   (0.72)
#  - conference_2_6 (reputation: 450):   50/80   (0.62)
#  - conference_8_7 (reputation: 450):   50/81   (0.62)
#  - conference_9_9 (reputation: 500):   50/128  (0.39)
#  - conference_7_7 (reputation: 400):   50/60   (0.83)
#  - conference_5_6 (reputation: 500):   41/134  (0.31)
#  - conference_6_8 (reputation: 450):   50/74   (0.68)
#  - conference_3_7 (reputation: 500):   38/120  (0.32)
#  - conference_1_9 (reputation: 450):   50/81   (0.62)
#  - conference_4_8 (reputation: 450):   51/86   (0.59)
#  - conference_0_8 (reputation: 450):   50/92   (0.54)
#  - conference_2_7 (reputation: 500):   21/89   (0.24)
#  - conference_7_8 (reputation: 400):   46/61   (0.75)
#  - conference_8_8 (reputation: 400):   50/59   (0.85)
#  - conference_6_9 (reputation: 400):   29/38   (0.76)
#  - conference_1_10 (reputation: 450):   29/43   (0.67)
#  - conference_9_10 (reputation: 450):   19/25   (0.76)
#  - conference_4_9 (reputation: 500):    8/24   (0.33)
#  - conference_8_9 (reputation: 500):    5/15   (0.33)
#  - conference_0_9 (reputation: 500):    0/5    (0.00)
#
# Analysis from network file
# --------------------
# simulation with 500 authors went on for 1001 steps.
# 339 agents remain.
# number of papers submitted: 7648
# number of papers accepted: 3582
# average number of coauthors per author: 3.05
# Agent strategies:
#   - before: diligent: 1.0
#   - after: diligent: 1.00
# mean reputation increase: 38.622
# mean effort put into submitted papers: 52.49
# median effort put into submitted papers: 52.00
# conference submissions, publications and acceptance rates:
#  - conference_0_0 (reputation: 400):   50/67   (0.75)
#  - conference_1_0 (reputation: 400):   50/55   (0.91)
#  - conference_2_0 (reputation: 500):   50/146  (0.34)
#  - conference_3_0 (reputation: 400):   50/58   (0.86)
#  - conference_4_0 (reputation: 450):   51/70   (0.73)
#  - conference_5_0 (reputation: 500):   50/143  (0.35)
#  - conference_6_0 (reputation: 400):   50/55   (0.91)
#  - conference_7_0 (reputation: 400):   51/58   (0.88)
#  - conference_8_0 (reputation: 450):   50/80   (0.62)
#  - conference_9_0 (reputation: 400):   51/60   (0.85)
#  - conference_6_1 (reputation: 500):   50/156  (0.32)
#  - conference_3_1 (reputation: 500):   50/121  (0.41)
#  - conference_7_1 (reputation: 450):   50/75   (0.67)
#  - conference_1_1 (reputation: 450):   50/70   (0.71)
#  - conference_9_1 (reputation: 450):   50/79   (0.63)
#  - conference_4_1 (reputation: 400):   50/55   (0.91)
#  - conference_0_1 (reputation: 500):   50/142  (0.35)
#  - conference_8_1 (reputation: 500):   51/146  (0.35)
#  - conference_4_2 (reputation: 500):   50/126  (0.40)
#  - conference_2_1 (reputation: 500):   50/160  (0.31)
#  - conference_7_2 (reputation: 500):   50/173  (0.29)
#  - conference_1_2 (reputation: 400):   50/56   (0.89)
#  - conference_9_2 (reputation: 500):   50/147  (0.34)
#  - conference_5_1 (reputation: 500):   50/160  (0.31)
#  - conference_3_2 (reputation: 450):   51/83   (0.61)
#  - conference_1_3 (reputation: 400):   50/59   (0.85)
#  - conference_6_2 (reputation: 400):   50/61   (0.82)
#  - conference_8_2 (reputation: 400):   51/57   (0.89)
#  - conference_0_2 (reputation: 400):   50/59   (0.85)
#  - conference_4_3 (reputation: 500):   50/126  (0.40)
#  - conference_1_4 (reputation: 400):   50/59   (0.85)
#  - conference_3_3 (reputation: 500):   50/134  (0.37)
#  - conference_6_3 (reputation: 400):   51/60   (0.85)
#  - conference_8_3 (reputation: 400):   50/64   (0.78)
#  - conference_2_2 (reputation: 400):   51/60   (0.85)
#  - conference_7_3 (reputation: 500):   50/130  (0.38)
#  - conference_9_3 (reputation: 450):   51/88   (0.58)
#  - conference_0_3 (reputation: 450):   50/84   (0.60)
#  - conference_1_5 (reputation: 500):   50/130  (0.38)
#  - conference_6_4 (reputation: 500):   50/205  (0.24)
#  - conference_8_4 (reputation: 500):   50/168  (0.30)
#  - conference_5_2 (reputation: 500):   50/145  (0.34)
#  - conference_2_3 (reputation: 500):   50/155  (0.32)
#  - conference_0_4 (reputation: 450):   50/75   (0.67)
#  - conference_3_4 (reputation: 500):   50/130  (0.38)
#  - conference_4_4 (reputation: 500):   50/201  (0.25)
#  - conference_9_4 (reputation: 500):   50/135  (0.37)
#  - conference_7_4 (reputation: 500):   50/130  (0.38)
#  - conference_1_6 (reputation: 500):   50/176  (0.28)
#  - conference_0_5 (reputation: 450):   51/78   (0.65)
#  - conference_8_5 (reputation: 450):   52/81   (0.64)
#  - conference_5_3 (reputation: 450):   50/81   (0.62)
#  - conference_2_4 (reputation: 500):   50/148  (0.34)
#  - conference_9_5 (reputation: 500):   51/149  (0.34)
#  - conference_6_5 (reputation: 450):   50/74   (0.68)
#  - conference_3_5 (reputation: 500):   50/195  (0.26)
#  - conference_0_6 (reputation: 500):   50/169  (0.30)
#  - conference_7_5 (reputation: 500):   50/160  (0.31)
#  - conference_1_7 (reputation: 400):   52/62   (0.84)
#  - conference_8_6 (reputation: 450):   50/87   (0.57)
#  - conference_4_5 (reputation: 450):   50/71   (0.70)
#  - conference_5_4 (reputation: 450):   50/78   (0.64)
#  - conference_6_6 (reputation: 500):   50/138  (0.36)
#  - conference_1_8 (reputation: 500):   50/165  (0.30)
#  - conference_8_7 (reputation: 500):   31/103  (0.30)
#  - conference_5_5 (reputation: 500):   25/88   (0.28)
#  - conference_4_6 (reputation: 450):   50/74   (0.68)
#  - conference_2_5 (reputation: 450):   50/84   (0.60)
#  - conference_9_6 (reputation: 500):   29/87   (0.33)
#  - conference_7_6 (reputation: 400):   49/57   (0.86)
#  - conference_3_6 (reputation: 400):   41/51   (0.80)
#  - conference_6_7 (reputation: 450):   30/54   (0.56)
#  - conference_0_7 (reputation: 400):   40/46   (0.87)
#  - conference_4_7 (reputation: 450):   17/26   (0.65)
#  - conference_2_6 (reputation: 450):    2/6    (0.33)
#  - conference_1_9 (reputation: 450):    3/4    (0.75)

# %%
reps1 = np.array([38.798, 46.278, 37.004, 44.386, 43.868])
print(np.mean(reps1))
print(np.std(reps1)/np.mean(reps1))
# Out:
# 42.06679999999999
# 0.08416275920864379

# %%
params2 = {
    "n_authors":500,
    "n_conferences":10,
    "render_mode":"network",
    "max_rewardless_steps":150,
    "max_agent_steps":5000, 
    "max_coauthors":10
}
strats2 = {
    "diligent": 0,
    "honest": 1,
    "malicious":0
}
run_experiment(5, params2, strats2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 14
#       1 params2 = {
#       2     "n_authors":500,
#       3     "n_conferences":10,
#    (...)
#       7     "max_coauthors":10
#       8 }
#       9 strats2 = {
#      10     "diligent": 0,
#      11     "honest": 1,
#      12     "malicious":0
#      13 }
# ---> 14 run_experiment(5, params2, strats2)
#
# Cell In[36], line 18, in run_experiment(num_runs, env_hyperparameters, strategy_probs)
#      16 for agent in env.agents:
#      17     if agent_to_strategy[agent] == "honest":
# ---> 18         actions[agent] = simple_policy(agent, env)
#      19     elif agent_to_strategy[agent] == "malicious":
#      20         actions[agent] = malicious_policy(agent, env)
#
# File ~/work/projects/conference-simulation/simulation/reputation-environment/custom_policies.py:6, in simple_policy(agent, environment)
#       4 new_mask = environment.action_masks[agent]
#       5 submittable = new_mask["submit"]["id"][1:]
# ----> 6 # only submit if total effort higher than 40
#       7 worthy_papers = (environment.global_observation["papers"]["total_effort"] > 40) & submittable
#       8 new_mask["submit"]["id"][1:] = worthy_papers.astype(np.int8)
#
# NameError: name 'np' is not defined

# %%
reps2 = [4.31, 5.566, 4.242, 6.732, 3.984]
print(np.mean(reps2))
print(np.std(reps2)/np.mean(reps2))
# Out:
# 4.966799999999999
# 0.20918870113700974

# %%
params3 = {
    "n_authors": 500,
    "n_conferences": 10,
    "render_mode": "network",
    "max_rewardless_steps": 150,
    "max_agent_steps": 5000, 
    "max_coauthors": 10
}
strats3 = {
    "diligent": 0,
    "honest": 0,
    "malicious": 1
}
run_experiment(5, params3, strats3)
# Out:
# Analysis from network file
# --------------------
# simulation with 500 authors went on for 495 steps.
# 0 agents remain.
# number of papers submitted: 3912
# number of papers accepted: 189
# average number of coauthors per author: 3.89
# Agent strategies:
#   - before: malicious: 1.0
#   - after:
# mean reputation increase: 2.062
# mean effort put into submitted papers: 23.05
# median effort put into submitted papers: 22.00
# conference submissions, publications and acceptance rates:
#  - conference_0_0 (reputation: 450):   18/402  (0.04)
#  - conference_1_0 (reputation: 450):   16/394  (0.04)
#  - conference_2_0 (reputation: 450):   19/396  (0.05)
#  - conference_3_0 (reputation: 500):   20/421  (0.05)
#  - conference_4_0 (reputation: 500):   19/396  (0.05)
#  - conference_5_0 (reputation: 500):   22/388  (0.06)
#  - conference_6_0 (reputation: 400):   15/379  (0.04)
#  - conference_7_0 (reputation: 450):   20/374  (0.05)
#  - conference_8_0 (reputation: 500):   19/374  (0.05)
#  - conference_9_0 (reputation: 500):   21/388  (0.05)
#
# Analysis from network file
# --------------------
# simulation with 500 authors went on for 592 steps.
# 0 agents remain.
# number of papers submitted: 4144
# number of papers accepted: 227
# average number of coauthors per author: 3.89
# Agent strategies:
#   - before: malicious: 1.0
#   - after:
# mean reputation increase: 2.44
# mean effort put into submitted papers: 23.00
# median effort put into submitted papers: 22.00
# conference submissions, publications and acceptance rates:
#  - conference_0_0 (reputation: 400):   21/419  (0.05)
#  - conference_1_0 (reputation: 400):   37/417  (0.09)
#  - conference_2_0 (reputation: 450):   25/407  (0.06)
#  - conference_3_0 (reputation: 500):   25/460  (0.05)
#  - conference_4_0 (reputation: 400):   22/424  (0.05)
#  - conference_5_0 (reputation: 450):   17/433  (0.04)
#  - conference_6_0 (reputation: 500):   13/373  (0.03)
#  - conference_7_0 (reputation: 400):   23/405  (0.06)
#  - conference_8_0 (reputation: 500):   20/398  (0.05)
#  - conference_9_0 (reputation: 500):   24/408  (0.06)
#
# Analysis from network file
# --------------------
# simulation with 500 authors went on for 648 steps.
# 0 agents remain.
# number of papers submitted: 4033
# number of papers accepted: 226
# average number of coauthors per author: 3.82
# Agent strategies:
#   - before: malicious: 1.0
#   - after:
# mean reputation increase: 2.504
# mean effort put into submitted papers: 23.03
# median effort put into submitted papers: 22.00
# conference submissions, publications and acceptance rates:
#  - conference_0_0 (reputation: 450):   20/399  (0.05)
#  - conference_1_0 (reputation: 500):   25/400  (0.06)
#  - conference_2_0 (reputation: 500):   24/402  (0.06)
#  - conference_3_0 (reputation: 500):   14/371  (0.04)
#  - conference_4_0 (reputation: 450):   23/440  (0.05)
#  - conference_5_0 (reputation: 450):   29/423  (0.07)
#  - conference_6_0 (reputation: 400):   27/407  (0.07)
#  - conference_7_0 (reputation: 500):   16/395  (0.04)
#  - conference_8_0 (reputation: 500):   21/411  (0.05)
#  - conference_9_0 (reputation: 450):   27/385  (0.07)
#
# Analysis from network file
# --------------------
# simulation with 500 authors went on for 576 steps.
# 0 agents remain.
# number of papers submitted: 4325
# number of papers accepted: 237
# average number of coauthors per author: 3.86
# Agent strategies:
#   - before: malicious: 1.0
#   - after:
# mean reputation increase: 2.534
# mean effort put into submitted papers: 23.05
# median effort put into submitted papers: 22.00
# conference submissions, publications and acceptance rates:
#  - conference_0_0 (reputation: 400):   19/444  (0.04)
#  - conference_1_0 (reputation: 500):   24/447  (0.05)
#  - conference_2_0 (reputation: 400):   25/432  (0.06)
#  - conference_3_0 (reputation: 450):   22/444  (0.05)
#  - conference_4_0 (reputation: 400):   23/459  (0.05)
#  - conference_5_0 (reputation: 500):   21/394  (0.05)
#  - conference_6_0 (reputation: 400):   26/457  (0.06)
#  - conference_7_0 (reputation: 500):   23/438  (0.05)
#  - conference_8_0 (reputation: 450):   33/371  (0.09)
#  - conference_9_0 (reputation: 450):   21/439  (0.05)
#
# Analysis from network file
# --------------------
# simulation with 500 authors went on for 543 steps.
# 0 agents remain.
# number of papers submitted: 3863
# number of papers accepted: 183
# average number of coauthors per author: 3.88
# Agent strategies:
#   - before: malicious: 1.0
#   - after:
# mean reputation increase: 1.92
# mean effort put into submitted papers: 23.03
# median effort put into submitted papers: 22.00
# conference submissions, publications and acceptance rates:
#  - conference_0_0 (reputation: 400):   17/390  (0.04)
#  - conference_1_0 (reputation: 450):   24/395  (0.06)
#  - conference_2_0 (reputation: 400):   14/347  (0.04)
#  - conference_3_0 (reputation: 400):   15/374  (0.04)
#  - conference_4_0 (reputation: 450):   15/412  (0.04)
#  - conference_5_0 (reputation: 400):   14/362  (0.04)
#  - conference_6_0 (reputation: 400):   21/384  (0.05)
#  - conference_7_0 (reputation: 500):   21/391  (0.05)
#  - conference_8_0 (reputation: 450):   19/410  (0.05)
#  - conference_9_0 (reputation: 400):   23/398  (0.06)

# %%
reps3 = [1.92, 2.534, 2.504, 2.44, 2.662]
print(np.mean(reps3))
print(np.std(reps3)/np.mean(reps3))
# Out:
# 2.412
# 0.10630040126025835

# %%
params3 = {
    "n_authors": 500,
    "n_conferences": 10,
    "render_mode": "network",
    "max_rewardless_steps": 150,
    "max_agent_steps": 5000, 
    "max_coauthors": 25
}
strats3 = {
    "diligent": 0,
    "honest": 0,
    "malicious": 1
}
run_experiment(5, params3, strats3)
# Out:
# Analysis from network file
# --------------------
# simulation with 500 authors went on for 568 steps.
# 0 agents remain.
# number of papers submitted: 4117
# number of papers accepted: 209
# average number of coauthors per author: 3.85
# Agent strategies:
#   - before: malicious: 1.0
#   - after:
# mean reputation increase: 2.226
# mean effort put into submitted papers: 23.04
# median effort put into submitted papers: 22.00
# conference submissions, publications and acceptance rates:
#  - conference_0_0 (reputation: 450):   26/396  (0.07)
#  - conference_1_0 (reputation: 400):   27/419  (0.06)
#  - conference_2_0 (reputation: 400):   13/430  (0.03)
#  - conference_3_0 (reputation: 450):   12/419  (0.03)
#  - conference_4_0 (reputation: 500):   22/410  (0.05)
#  - conference_5_0 (reputation: 450):   20/385  (0.05)
#  - conference_6_0 (reputation: 500):   17/421  (0.04)
#  - conference_7_0 (reputation: 400):   27/426  (0.06)
#  - conference_8_0 (reputation: 500):   27/411  (0.07)
#  - conference_9_0 (reputation: 450):   18/400  (0.04)
#
# Analysis from network file
# --------------------
# simulation with 500 authors went on for 580 steps.
# 0 agents remain.
# number of papers submitted: 4008
# number of papers accepted: 218
# average number of coauthors per author: 3.87
# Agent strategies:
#   - before: malicious: 1.0
#   - after:
# mean reputation increase: 2.328
# mean effort put into submitted papers: 22.99
# median effort put into submitted papers: 22.00
# conference submissions, publications and acceptance rates:
#  - conference_0_0 (reputation: 400):   18/409  (0.04)
#  - conference_1_0 (reputation: 450):   17/445  (0.04)
#  - conference_2_0 (reputation: 400):   24/412  (0.06)
#  - conference_3_0 (reputation: 450):   13/405  (0.03)
#  - conference_4_0 (reputation: 500):   19/387  (0.05)
#  - conference_5_0 (reputation: 400):   15/377  (0.04)
#  - conference_6_0 (reputation: 500):   23/345  (0.07)
#  - conference_7_0 (reputation: 450):   28/419  (0.07)
#  - conference_8_0 (reputation: 400):   24/389  (0.06)
#  - conference_9_0 (reputation: 400):   37/420  (0.09)
#
# Analysis from network file
# --------------------
# simulation with 500 authors went on for 636 steps.
# 0 agents remain.
# number of papers submitted: 3889
# number of papers accepted: 184
# average number of coauthors per author: 3.88
# Agent strategies:
#   - before: malicious: 1.0
#   - after:
# mean reputation increase: 2.052
# mean effort put into submitted papers: 23.05
# median effort put into submitted papers: 22.00
# conference submissions, publications and acceptance rates:
#  - conference_0_0 (reputation: 450):   24/388  (0.06)
#  - conference_1_0 (reputation: 450):   17/375  (0.05)
#  - conference_2_0 (reputation: 400):   23/363  (0.06)
#  - conference_3_0 (reputation: 500):    9/404  (0.02)
#  - conference_4_0 (reputation: 400):   19/377  (0.05)
#  - conference_5_0 (reputation: 400):   18/400  (0.04)
#  - conference_6_0 (reputation: 450):   18/405  (0.04)
#  - conference_7_0 (reputation: 500):   18/400  (0.04)
#  - conference_8_0 (reputation: 500):   20/400  (0.05)
#  - conference_9_0 (reputation: 500):   18/377  (0.05)
#
# Analysis from network file
# --------------------
# simulation with 500 authors went on for 602 steps.
# 0 agents remain.
# number of papers submitted: 3916
# number of papers accepted: 186
# average number of coauthors per author: 3.87
# Agent strategies:
#   - before: malicious: 1.0
#   - after:
# mean reputation increase: 1.932
# mean effort put into submitted papers: 22.98
# median effort put into submitted papers: 22.00
# conference submissions, publications and acceptance rates:
#  - conference_0_0 (reputation: 400):   17/380  (0.04)
#  - conference_1_0 (reputation: 400):   17/389  (0.04)
#  - conference_2_0 (reputation: 450):   23/394  (0.06)
#  - conference_3_0 (reputation: 450):   19/413  (0.05)
#  - conference_4_0 (reputation: 500):   15/384  (0.04)
#  - conference_5_0 (reputation: 450):   14/431  (0.03)
#  - conference_6_0 (reputation: 500):   23/404  (0.06)
#  - conference_7_0 (reputation: 400):   21/395  (0.05)
#  - conference_8_0 (reputation: 400):   20/371  (0.05)
#  - conference_9_0 (reputation: 400):   17/355  (0.05)
#
# Analysis from network file
# --------------------
# simulation with 500 authors went on for 512 steps.
# 0 agents remain.
# number of papers submitted: 3955
# number of papers accepted: 191
# average number of coauthors per author: 3.87
# Agent strategies:
#   - before: malicious: 1.0
#   - after:
# mean reputation increase: 2.164
# mean effort put into submitted papers: 23.00
# median effort put into submitted papers: 22.00
# conference submissions, publications and acceptance rates:
#  - conference_0_0 (reputation: 400):   21/404  (0.05)
#  - conference_1_0 (reputation: 450):   19/404  (0.05)
#  - conference_2_0 (reputation: 500):   26/362  (0.07)
#  - conference_3_0 (reputation: 400):   11/373  (0.03)
#  - conference_4_0 (reputation: 450):   20/418  (0.05)
#  - conference_5_0 (reputation: 500):   14/365  (0.04)
#  - conference_6_0 (reputation: 500):   23/400  (0.06)
#  - conference_7_0 (reputation: 500):   16/425  (0.04)
#  - conference_8_0 (reputation: 500):   25/392  (0.06)
#  - conference_9_0 (reputation: 500):   16/412  (0.04)

# %%
params5 = {
    "n_authors": 500,
    "n_conferences": 10,
    "render_mode": "network",
    "max_rewardless_steps": 150,
    "max_agent_steps": 5000, 
    "max_coauthors": 25
}
strats5 = {
    "diligent": 0,
    "honest": 1,
    "malicious": 0
}
run_experiment(5, params5, strats5)
# Out:
# Analysis from network file
# --------------------
# simulation with 500 authors went on for 746 steps.
# 0 agents remain.
# number of papers submitted: 3142
# number of papers accepted: 638
# average number of coauthors per author: 3.02
# Agent strategies:
#   - before: honest: 1.0
#   - after:
# mean reputation increase: 6.27
# mean effort put into submitted papers: 42.48
# median effort put into submitted papers: 42.00
# conference submissions, publications and acceptance rates:
#  - conference_0_0 (reputation: 400):   50/116  (0.43)
#  - conference_1_0 (reputation: 450):   50/276  (0.18)
#  - conference_2_0 (reputation: 500):   35/319  (0.11)
#  - conference_3_0 (reputation: 400):   50/121  (0.41)
#  - conference_4_0 (reputation: 500):   29/316  (0.09)
#  - conference_5_0 (reputation: 400):   50/131  (0.38)
#  - conference_6_0 (reputation: 400):   50/117  (0.43)
#  - conference_7_0 (reputation: 500):   25/303  (0.08)
#  - conference_8_0 (reputation: 400):   51/109  (0.47)
#  - conference_9_0 (reputation: 450):   50/249  (0.20)
#  - conference_8_1 (reputation: 500):   21/226  (0.09)
#  - conference_3_1 (reputation: 500):   13/191  (0.07)
#  - conference_0_1 (reputation: 450):   41/218  (0.19)
#  - conference_6_1 (reputation: 400):   50/114  (0.44)
#  - conference_5_1 (reputation: 400):   50/122  (0.41)
#  - conference_6_2 (reputation: 450):   10/74   (0.14)
#  - conference_9_1 (reputation: 450):    7/46   (0.15)
#  - conference_1_1 (reputation: 500):    3/48   (0.06)
#  - conference_5_2 (reputation: 500):    3/46   (0.07)
#
# Analysis from network file
# --------------------
# simulation with 500 authors went on for 878 steps.
# 0 agents remain.
# number of papers submitted: 3591
# number of papers accepted: 749
# average number of coauthors per author: 3.02
# Agent strategies:
#   - before: honest: 1.0
#   - after:
# mean reputation increase: 7.306
# mean effort put into submitted papers: 42.47
# median effort put into submitted papers: 42.00
# conference submissions, publications and acceptance rates:
#  - conference_0_0 (reputation: 450):   50/332  (0.15)
#  - conference_1_0 (reputation: 400):   50/129  (0.39)
#  - conference_2_0 (reputation: 400):   50/127  (0.39)
#  - conference_3_0 (reputation: 400):   50/123  (0.41)
#  - conference_4_0 (reputation: 400):   50/121  (0.41)
#  - conference_5_0 (reputation: 450):   50/284  (0.18)
#  - conference_6_0 (reputation: 450):   50/262  (0.19)
#  - conference_7_0 (reputation: 450):   50/265  (0.19)
#  - conference_8_0 (reputation: 400):   50/145  (0.34)
#  - conference_9_0 (reputation: 450):   50/242  (0.21)
#  - conference_4_1 (reputation: 400):   50/146  (0.34)
#  - conference_2_1 (reputation: 450):   37/244  (0.15)
#  - conference_1_1 (reputation: 500):   23/261  (0.09)
#  - conference_3_1 (reputation: 450):   33/220  (0.15)
#  - conference_8_1 (reputation: 450):   37/210  (0.18)
#  - conference_6_1 (reputation: 500):   10/126  (0.08)
#  - conference_9_1 (reputation: 450):   27/123  (0.22)
#  - conference_4_2 (reputation: 500):   14/109  (0.13)
#  - conference_7_1 (reputation: 450):   15/72   (0.21)
#  - conference_5_1 (reputation: 500):    3/50   (0.06)
#
# Analysis from network file
# --------------------
# simulation with 500 authors went on for 811 steps.
# 0 agents remain.
# number of papers submitted: 3505
# number of papers accepted: 735
# average number of coauthors per author: 3.00
# Agent strategies:
#   - before: honest: 1.0
#   - after:
# mean reputation increase: 7.186
# mean effort put into submitted papers: 42.55
# median effort put into submitted papers: 42.00
# conference submissions, publications and acceptance rates:
#  - conference_0_0 (reputation: 450):   51/291  (0.18)
#  - conference_1_0 (reputation: 400):   51/118  (0.43)
#  - conference_2_0 (reputation: 400):   50/138  (0.36)
#  - conference_3_0 (reputation: 500):   39/368  (0.11)
#  - conference_4_0 (reputation: 400):   50/112  (0.45)
#  - conference_5_0 (reputation: 500):   45/389  (0.12)
#  - conference_6_0 (reputation: 400):   50/177  (0.28)
#  - conference_7_0 (reputation: 400):   50/128  (0.39)
#  - conference_8_0 (reputation: 500):   28/326  (0.09)
#  - conference_9_0 (reputation: 400):   50/113  (0.44)
#  - conference_4_1 (reputation: 500):   13/215  (0.06)
#  - conference_7_1 (reputation: 400):   51/123  (0.41)
#  - conference_1_1 (reputation: 450):   42/234  (0.18)
#  - conference_9_1 (reputation: 450):   40/232  (0.17)
#  - conference_2_1 (reputation: 450):   34/194  (0.18)
#  - conference_6_1 (reputation: 400):   50/121  (0.41)
#  - conference_7_2 (reputation: 500):    8/108  (0.07)
#  - conference_0_1 (reputation: 400):   27/72   (0.38)
#  - conference_6_2 (reputation: 450):    6/46   (0.13)
#
# Analysis from network file
# --------------------
# simulation with 500 authors went on for 1001 steps.
# 1 agents remain.
# number of papers submitted: 3261
# number of papers accepted: 651
# average number of coauthors per author: 3.03
# Agent strategies:
#   - before: honest: 1.0
#   - after: honest: 1.00
# mean reputation increase: 6.24
# mean effort put into submitted papers: 42.43
# median effort put into submitted papers: 42.00
# conference submissions, publications and acceptance rates:
#  - conference_0_0 (reputation: 400):   51/126  (0.40)
#  - conference_1_0 (reputation: 400):   50/107  (0.47)
#  - conference_2_0 (reputation: 500):   25/320  (0.08)
#  - conference_3_0 (reputation: 450):   50/252  (0.20)
#  - conference_4_0 (reputation: 450):   50/307  (0.16)
#  - conference_5_0 (reputation: 450):   48/282  (0.17)
#  - conference_6_0 (reputation: 400):   50/138  (0.36)
#  - conference_7_0 (reputation: 450):   50/305  (0.16)
#  - conference_8_0 (reputation: 450):   50/205  (0.24)
#  - conference_9_0 (reputation: 450):   50/295  (0.17)
#  - conference_1_1 (reputation: 500):   19/225  (0.08)
#  - conference_0_1 (reputation: 400):   50/162  (0.31)
#  - conference_6_1 (reputation: 400):   50/152  (0.33)
#  - conference_8_1 (reputation: 450):   22/153  (0.14)
#  - conference_3_1 (reputation: 500):    3/75   (0.04)
#  - conference_9_1 (reputation: 450):    8/50   (0.16)
#  - conference_4_1 (reputation: 400):   13/37   (0.35)
#  - conference_6_2 (reputation: 450):    4/31   (0.13)
#  - conference_0_2 (reputation: 500):    5/25   (0.20)
#  - conference_7_1 (reputation: 450):    3/14   (0.21)
#
# Analysis from network file
# --------------------
# simulation with 500 authors went on for 866 steps.
# 0 agents remain.
# number of papers submitted: 3838
# number of papers accepted: 850
# average number of coauthors per author: 3.02
# Agent strategies:
#   - before: honest: 1.0
#   - after:
# mean reputation increase: 8.122
# mean effort put into submitted papers: 42.47
# median effort put into submitted papers: 42.00
# conference submissions, publications and acceptance rates:
#  - conference_0_0 (reputation: 450):   50/206  (0.24)
#  - conference_1_0 (reputation: 400):   50/157  (0.32)
#  - conference_2_0 (reputation: 450):   50/279  (0.18)
#  - conference_3_0 (reputation: 400):   50/127  (0.39)
#  - conference_4_0 (reputation: 400):   50/125  (0.40)
#  - conference_5_0 (reputation: 400):   50/129  (0.39)
#  - conference_6_0 (reputation: 450):   50/296  (0.17)
#  - conference_7_0 (reputation: 400):   50/118  (0.42)
#  - conference_8_0 (reputation: 400):   50/135  (0.37)
#  - conference_9_0 (reputation: 500):   32/402  (0.08)
#  - conference_7_1 (reputation: 450):   31/255  (0.12)
#  - conference_3_1 (reputation: 400):   50/121  (0.41)
#  - conference_8_1 (reputation: 500):   25/258  (0.10)
#  - conference_4_1 (reputation: 450):   47/242  (0.19)
#  - conference_5_1 (reputation: 400):   50/129  (0.39)
#  - conference_1_1 (reputation: 400):   50/139  (0.36)
#  - conference_0_1 (reputation: 500):   12/191  (0.06)
#  - conference_3_2 (reputation: 450):   25/148  (0.17)
#  - conference_2_1 (reputation: 500):    9/94   (0.10)
#  - conference_5_2 (reputation: 450):   18/103  (0.17)
#  - conference_1_2 (reputation: 400):   37/101  (0.37)
#  - conference_6_1 (reputation: 450):   14/83   (0.17)

# %%
params7 = {
    "n_authors": 500,
    "n_conferences": 25,
    "render_mode": "network",
    "max_rewardless_steps": 150,
    "max_agent_steps": 5000, 
    "max_coauthors": 10
}
strats7 = {
    "diligent": 0,
    "honest": 0,
    "malicious": 1
}
run_experiment(5, params7, strats7)
# Out:
# Analysis from network file
# --------------------
# simulation with 500 authors went on for 526 steps.
# 0 agents remain.
# number of papers submitted: 4034
# number of papers accepted: 220
# average number of coauthors per author: 3.83
# Agent strategies:
#   - before: malicious: 1.0
#   - after:
# mean reputation increase: 2.402
# mean effort put into submitted papers: 22.92
# median effort put into submitted papers: 22.00
# conference submissions, publications and acceptance rates:
#  - conference_0_0 (reputation: 400):   12/140  (0.09)
#  - conference_1_0 (reputation: 400):    9/170  (0.05)
#  - conference_2_0 (reputation: 450):    9/153  (0.06)
#  - conference_3_0 (reputation: 500):    7/160  (0.04)
#  - conference_4_0 (reputation: 500):   12/159  (0.08)
#  - conference_5_0 (reputation: 500):    4/140  (0.03)
#  - conference_6_0 (reputation: 500):    5/160  (0.03)
#  - conference_7_0 (reputation: 500):    9/150  (0.06)
#  - conference_8_0 (reputation: 450):    9/155  (0.06)
#  - conference_9_0 (reputation: 450):   12/165  (0.07)
#  - conference_10_0 (reputation: 400):   15/180  (0.08)
#  - conference_11_0 (reputation: 500):    9/154  (0.06)
#  - conference_12_0 (reputation: 500):    9/186  (0.05)
#  - conference_13_0 (reputation: 400):    8/146  (0.05)
#  - conference_14_0 (reputation: 500):    8/170  (0.05)
#  - conference_15_0 (reputation: 400):    9/144  (0.06)
#  - conference_16_0 (reputation: 400):    7/171  (0.04)
#  - conference_17_0 (reputation: 450):    6/194  (0.03)
#  - conference_18_0 (reputation: 400):    6/153  (0.04)
#  - conference_19_0 (reputation: 500):    9/172  (0.05)
#  - conference_20_0 (reputation: 500):   14/165  (0.08)
#  - conference_21_0 (reputation: 400):    6/165  (0.04)
#  - conference_22_0 (reputation: 400):   10/175  (0.06)
#  - conference_23_0 (reputation: 450):    9/154  (0.06)
#  - conference_24_0 (reputation: 500):    7/153  (0.05)
#
# Analysis from network file
# --------------------
# simulation with 500 authors went on for 476 steps.
# 0 agents remain.
# number of papers submitted: 3933
# number of papers accepted: 201
# average number of coauthors per author: 3.87
# Agent strategies:
#   - before: malicious: 1.0
#   - after:
# mean reputation increase: 2.162
# mean effort put into submitted papers: 23.01
# median effort put into submitted papers: 22.00
# conference submissions, publications and acceptance rates:
#  - conference_0_0 (reputation: 500):   10/162  (0.06)
#  - conference_1_0 (reputation: 450):    6/160  (0.04)
#  - conference_2_0 (reputation: 400):    5/180  (0.03)
#  - conference_3_0 (reputation: 450):    8/153  (0.05)
#  - conference_4_0 (reputation: 500):   13/186  (0.07)
#  - conference_5_0 (reputation: 500):    8/169  (0.05)
#  - conference_6_0 (reputation: 400):   13/156  (0.08)
#  - conference_7_0 (reputation: 400):    9/159  (0.06)
#  - conference_8_0 (reputation: 400):    8/168  (0.05)
#  - conference_9_0 (reputation: 450):    6/156  (0.04)
#  - conference_10_0 (reputation: 500):    9/161  (0.06)
#  - conference_11_0 (reputation: 450):    9/160  (0.06)
#  - conference_12_0 (reputation: 400):    8/164  (0.05)
#  - conference_13_0 (reputation: 450):    7/150  (0.05)
#  - conference_14_0 (reputation: 500):   10/140  (0.07)
#  - conference_15_0 (reputation: 450):    7/142  (0.05)
#  - conference_16_0 (reputation: 400):    5/168  (0.03)
#  - conference_17_0 (reputation: 500):    2/135  (0.01)
#  - conference_18_0 (reputation: 400):    8/149  (0.05)
#  - conference_19_0 (reputation: 450):    6/153  (0.04)
#  - conference_20_0 (reputation: 400):    6/154  (0.04)
#  - conference_21_0 (reputation: 400):   10/149  (0.07)
#  - conference_22_0 (reputation: 450):    9/163  (0.06)
#  - conference_23_0 (reputation: 400):   11/140  (0.08)
#  - conference_24_0 (reputation: 450):    8/156  (0.05)
#
# Analysis from network file
# --------------------
# simulation with 500 authors went on for 586 steps.
# 0 agents remain.
# number of papers submitted: 4199
# number of papers accepted: 228
# average number of coauthors per author: 3.85
# Agent strategies:
#   - before: malicious: 1.0
#   - after:
# mean reputation increase: 2.462
# mean effort put into submitted papers: 23.02
# median effort put into submitted papers: 22.00
# conference submissions, publications and acceptance rates:
#  - conference_0_0 (reputation: 450):   13/161  (0.08)
#  - conference_1_0 (reputation: 400):   13/175  (0.07)
#  - conference_2_0 (reputation: 500):   14/188  (0.07)
#  - conference_3_0 (reputation: 500):   10/166  (0.06)
#  - conference_4_0 (reputation: 400):    6/164  (0.04)
#  - conference_5_0 (reputation: 500):   15/180  (0.08)
#  - conference_6_0 (reputation: 500):    5/167  (0.03)
#  - conference_7_0 (reputation: 400):   14/190  (0.07)
#  - conference_8_0 (reputation: 450):   10/176  (0.06)
#  - conference_9_0 (reputation: 500):    9/156  (0.06)
#  - conference_10_0 (reputation: 450):    7/164  (0.04)
#  - conference_11_0 (reputation: 450):    4/164  (0.02)
#  - conference_12_0 (reputation: 450):    4/167  (0.02)
#  - conference_13_0 (reputation: 400):    9/168  (0.05)
#  - conference_14_0 (reputation: 500):    9/187  (0.05)
#  - conference_15_0 (reputation: 500):    8/169  (0.05)
#  - conference_16_0 (reputation: 400):   15/172  (0.09)
#  - conference_17_0 (reputation: 500):    4/170  (0.02)
#  - conference_18_0 (reputation: 450):   10/166  (0.06)
#  - conference_19_0 (reputation: 450):   10/156  (0.06)
#  - conference_20_0 (reputation: 400):    8/150  (0.05)
#  - conference_21_0 (reputation: 400):    4/171  (0.02)
#  - conference_22_0 (reputation: 400):   13/160  (0.08)
#  - conference_23_0 (reputation: 450):    8/155  (0.05)
#  - conference_24_0 (reputation: 500):    6/157  (0.04)
#
# Analysis from network file
# --------------------
# simulation with 500 authors went on for 539 steps.
# 0 agents remain.
# number of papers submitted: 3970
# number of papers accepted: 184
# average number of coauthors per author: 3.83
# Agent strategies:
#   - before: malicious: 1.0
#   - after:
# mean reputation increase: 1.992
# mean effort put into submitted papers: 22.99
# median effort put into submitted papers: 22.00
# conference submissions, publications and acceptance rates:
#  - conference_0_0 (reputation: 400):    7/155  (0.05)
#  - conference_1_0 (reputation: 400):   13/170  (0.08)
#  - conference_2_0 (reputation: 400):    9/136  (0.07)
#  - conference_3_0 (reputation: 500):    7/175  (0.04)
#  - conference_4_0 (reputation: 400):    7/174  (0.04)
#  - conference_5_0 (reputation: 500):    9/172  (0.05)
#  - conference_6_0 (reputation: 400):    7/155  (0.05)
#  - conference_7_0 (reputation: 450):    8/158  (0.05)
#  - conference_8_0 (reputation: 450):    3/145  (0.02)
#  - conference_9_0 (reputation: 400):    8/158  (0.05)
#  - conference_10_0 (reputation: 400):   13/174  (0.07)
#  - conference_11_0 (reputation: 400):    7/142  (0.05)
#  - conference_12_0 (reputation: 450):    4/174  (0.02)
#  - conference_13_0 (reputation: 500):    4/133  (0.03)
#  - conference_14_0 (reputation: 450):    3/149  (0.02)
#  - conference_15_0 (reputation: 500):   11/163  (0.07)
#  - conference_16_0 (reputation: 400):    6/155  (0.04)
#  - conference_17_0 (reputation: 400):   10/155  (0.06)
#  - conference_18_0 (reputation: 500):    5/154  (0.03)
#  - conference_19_0 (reputation: 500):   11/162  (0.07)
#  - conference_20_0 (reputation: 400):    9/138  (0.07)
#  - conference_21_0 (reputation: 450):    6/173  (0.03)
#  - conference_22_0 (reputation: 500):    3/164  (0.02)
#  - conference_23_0 (reputation: 400):    8/155  (0.05)
#  - conference_24_0 (reputation: 450):    6/181  (0.03)
#
# Analysis from network file
# --------------------
# simulation with 500 authors went on for 570 steps.
# 0 agents remain.
# number of papers submitted: 3604
# number of papers accepted: 171
# average number of coauthors per author: 3.90
# Agent strategies:
#   - before: malicious: 1.0
#   - after:
# mean reputation increase: 1.836
# mean effort put into submitted papers: 23.03
# median effort put into submitted papers: 22.00
# conference submissions, publications and acceptance rates:
#  - conference_0_0 (reputation: 450):    8/138  (0.06)
#  - conference_1_0 (reputation: 400):   10/149  (0.07)
#  - conference_2_0 (reputation: 400):    7/149  (0.05)
#  - conference_3_0 (reputation: 400):    3/134  (0.02)
#  - conference_4_0 (reputation: 450):   11/122  (0.09)
#  - conference_5_0 (reputation: 500):    7/144  (0.05)
#  - conference_6_0 (reputation: 400):    6/142  (0.04)
#  - conference_7_0 (reputation: 450):    7/154  (0.05)
#  - conference_8_0 (reputation: 450):    6/133  (0.05)
#  - conference_9_0 (reputation: 500):   11/151  (0.07)
#  - conference_10_0 (reputation: 400):   11/167  (0.07)
#  - conference_11_0 (reputation: 500):    4/124  (0.03)
#  - conference_12_0 (reputation: 450):    8/132  (0.06)
#  - conference_13_0 (reputation: 400):   10/148  (0.07)
#  - conference_14_0 (reputation: 500):    5/153  (0.03)
#  - conference_15_0 (reputation: 450):    6/152  (0.04)
#  - conference_16_0 (reputation: 450):    5/163  (0.03)
#  - conference_17_0 (reputation: 500):    6/123  (0.05)
#  - conference_18_0 (reputation: 400):    4/144  (0.03)
#  - conference_19_0 (reputation: 400):   10/142  (0.07)
#  - conference_20_0 (reputation: 500):    4/158  (0.03)
#  - conference_21_0 (reputation: 400):    7/157  (0.04)
#  - conference_22_0 (reputation: 500):    5/133  (0.04)
#  - conference_23_0 (reputation: 400):    6/139  (0.04)
#  - conference_24_0 (reputation: 500):    4/153  (0.03)

# %%
params8 = {
    "n_authors": 500,
    "n_conferences": 25,
    "render_mode": "network",
    "max_rewardless_steps": 150,
    "max_agent_steps": 5000, 
    "max_coauthors": 10
}
strats8 = {
    "diligent": 0,
    "honest": 1,
    "malicious": 0
}
run_experiment(5, params8, strats8)
